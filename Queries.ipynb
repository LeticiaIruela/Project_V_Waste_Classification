# %% [markdown]
# # QUERIES

# %%
import os
from dotenv import load_dotenv
import sqlalchemy as alch
import src.sql_queries as sql
import pymysql
import sqlalchemy as alch 
from getpass import getpass
import pandas as pd
import src.sql_queries as sql

# %% [markdown]
# ### 3.1 Connection to SQL

# %% [markdown]
# Establish connection to MySQL Workbench

# %%
def connection_sql(password, dbName):
    load_dotenv()
    connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
    engine = alch.create_engine(connectionData)
    return engine

# %%
password = os.getenv("password")

# %%
engine=sql.sql_connection("project_v")

# %% [markdown]
# # Waste generated Europe

# %% [markdown]
# What is the total waste generated in Europe across the years?

# %%
query='''
SELECT  
    SUM(`2011`) AS Total_2011,
    SUM(`2012`) AS Total_2012,
    SUM(`2013`) AS Total_2013,
    SUM(`2014`) AS Total_2014,
    SUM(`2015`) AS Total_2015,
    SUM(`2016`) AS Total_2016,
    SUM(`2017`) AS Total_2017,
    SUM(`2018`) AS Total_2018,
    SUM(`2019`) AS Total_2019,
    SUM(`2020`) AS Total_2020
FROM df_generated_global_packaging
WHERE COUNTRY <> 'European Union - 27 countries (from 2020)'
'''
pd.read_sql_query (query, engine)
# Out:
#    Total_2011  Total_2012  Total_2013  Total_2014  Total_2015  Total_2016
# 0      3810.2     3774.52     3884.24     3980.27     4082.61     4177.17  \
#
#    Total_2017  Total_2018  Total_2019  Total_2020
# 0     4296.82     4300.25     4439.83     4144.75

# %% [markdown]
# What are the 10 countries with more garbagge generated per capita?

# %%
query='''
SELECT COUNTRY, SUM(`2011` + `2012` + `2013` + `2014` + `2015` + `2016` + `2017` + `2018` + `2019` + `2020`) AS Total_Generation
FROM df_generated_global_packaging
GROUP BY COUNTRY
ORDER BY Total_Generation DESC
LIMIT 10;
'''
pd.read_sql_query (query, engine)
# Out:
#                                             COUNTRY  Total_Generation
# 0  Germany (until 1990 former territory of the FRG)           2193.63
# 1                                        Luxembourg           2149.41
# 2                                           Ireland           2054.93
# 3                                             Italy           2038.95
# 4                                            France           1897.15
# 5                                       Netherlands           1719.97
# 6         European Union - 27 countries (from 2020)           1666.36
# 7                                     Liechtenstein           1663.77
# 8                                           Denmark           1647.43
# 9                                           Estonia           1625.22

# %% [markdown]
# # Recycling ratio

# %% [markdown]
# Which is the average total ratio of recyling per year in europe?

# %%
query = '''
SELECT
    AVG(`2011`) AS Avg_ratio_2011,
    AVG(`2012`) AS Avg_ratio_2012,
    AVG(`2013`) AS Avg_ratio_2013,
    AVG(`2014`) AS Avg_ratio_2014,
    AVG(`2015`) AS Avg_ratio_2015,
    AVG(`2016`) AS Avg_ratio_2016,
    AVG(`2017`) AS Avg_ratio_2017,
    AVG(`2018`) AS Avg_ratio_2018,
    AVG(`2019`) AS Avg_ratio_2019,
    AVG(`2020`) AS Avg_ratio_2020
FROM
    recy_ratio_europe;
'''

pd.read_sql_query(query, engine)
# Out:
#    Avg_ratio_2011  Avg_ratio_2012  Avg_ratio_2013  Avg_ratio_2014
# 0       62.615385       63.084615       63.277885       64.329808  \
#
#    Avg_ratio_2015  Avg_ratio_2016  Avg_ratio_2017  Avg_ratio_2018
# 0       64.791346       66.374038       65.556731       65.561538  \
#
#    Avg_ratio_2019  Avg_ratio_2020
# 0       65.858654       64.446154

# %%
query = '''
SELECT
    COUNTRY,
    AVG(`2011`) AS Avg_ratio_2011,
    AVG(`2012`) AS Avg_ratio_2012,
    AVG(`2013`) AS Avg_ratio_2013,
    AVG(`2014`) AS Avg_ratio_2014,
    AVG(`2015`) AS Avg_ratio_2015,
    AVG(`2016`) AS Avg_ratio_2016,
    AVG(`2017`) AS Avg_ratio_2017,
    AVG(`2018`) AS Avg_ratio_2018,
    AVG(`2019`) AS Avg_ratio_2019,
    AVG(`2020`) AS Avg_ratio_2020
FROM
    recy_ratio_europe
GROUP BY
    COUNTRY
ORDER BY
    Avg_ratio_2011 DESC
LIMIT 10;
'''

pd.read_sql_query(query, engine)
# Out:
#                                             COUNTRY  Avg_ratio_2011
# 0                                           Belgium          78.000  \
# 1                                          Slovenia          73.725
# 2  Germany (until 1990 former territory of the FRG)          73.625
# 3                                       Netherlands          73.500
# 4                                           Czechia          72.900
# 5                                           Ireland          72.775
# 6                                            Sweden          68.250
# 7                                        Luxembourg          67.850
# 8                                           Finland          67.200
# 9                                           Austria          66.975
#
#    Avg_ratio_2012  Avg_ratio_2013  Avg_ratio_2014  Avg_ratio_2015
# 0          77.900          76.700          78.425          78.700  \
# 1          74.425          78.825          79.850          76.125
# ...

# %% [markdown]
# What are the top 10 countries with higher ratio over the years?

# %%
query='''
SELECT COUNTRY, MAX(`2011`) AS Max_2011, MAX(`2012`) AS Max_2012, MAX(`2013`) AS Max_2013, MAX(`2014`) AS Max_2014, MAX(`2015`) AS Max_2015, MAX(`2016`) AS Max_2016, MAX(`2017`) AS Max_2017, MAX(`2018`) AS Max_2018, MAX(`2019`) AS Max_2019, MAX(`2020`) AS Max_2020
FROM recy_ratio_europe
GROUP BY COUNTRY
ORDER BY MAX(`2011` + `2012` + `2013` + `2014` + `2015` + `2016` + `2017` + `2018` + `2019` + `2020`) DESC
LIMIT 10;
'''
pd.read_sql_query (query, engine)
# Out:
#        COUNTRY  Max_2011  Max_2012  Max_2013  Max_2014  Max_2015  Max_2016
# 0      Finland      96.8      99.2      97.6     101.2     111.6     114.6  \
# 1      Belgium     100.0     100.0     100.0     100.0     100.0     100.0
# 2   Luxembourg      94.4      94.6      94.8      94.5      97.0      97.5
# 3     Slovenia      82.3      87.3      85.9      99.3      98.5     100.2
# 4       Cyprus      88.3      88.9      97.3      96.7      96.6      99.7
# 5       Sweden      91.9      88.2      89.0      94.7      93.6      92.8
# 6       France      88.0      91.8      95.8      94.1      92.0      93.9
# 7      Czechia      90.5      85.9      87.6      88.6      90.1      93.7
# 8       Norway      87.4      87.6      86.2      87.8      86.8      89.4
# 9  Netherlands      88.6      88.9      88.2      85.9      85.4      85.4
#
#    Max_2017  Max_2018  Max_2019  Max_2020
# 0     116.1     116.0     115.9     123.1
# 1     100.0     100.0     100.0      96.9
# ...

# %%
query='''
SELECT *
FROM recy_ratio_europe
'''
pd.read_sql_query (query, engine)
# Out:
#      MyUnknownColumn                                           COUNTRY  2009
# 0                  9         European Union - 27 countries (from 2020)  83.3  \
# 1                 12                                           Belgium  88.0
# 2                 14                                           Czechia  93.9
# 3                 15                                           Denmark  93.5
# 4                 16  Germany (until 1990 former territory of the FRG)  91.1
# ..               ...                                               ...   ...
# 99                36                                          Slovakia  51.6
# 100               37                                           Finland  45.1
# 101               38                                            Sweden  90.4
# 102               40                                     Liechtenstein  63.4
# 103               41                                            Norway  85.7
#
# ...

# %% [markdown]
# Average per material from 2011 to 2020

# %%
query='''
SELECT Material, AVG(`2009`) AS Avg_Recycling_Ratio_2009, AVG(`2010`) AS Avg_Recycling_Ratio_2010, ...
FROM recy_ratio_europe
GROUP BY Material
'''
pd.read_sql_query (query, engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:1905, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1904     if not evt_handled:
# -> 1905         self.dialect.do_execute(
#    1906             cursor, statement, parameters, context
#    1907         )
#    1909 if self._has_events or self.engine._has_events:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# ...

# %% [markdown]
# 3 Countries with a ratio improvement across the years

# %%
query='''
SELECT
    Country,
    (`2012` - `2011`) AS Increment_2012,
    (`2013` - `2012`) AS Increment_2013,
    (`2014` - `2013`) AS Increment_2014,
    (`2015` - `2014`) AS Increment_2015,
    (`2016` - `2015`) AS Increment_2016,
    (`2017` - `2016`) AS Increment_2017,
    (`2018` - `2017`) AS Increment_2018,
    (`2019` - `2018`) AS Increment_2019,
    (`2020` - `2019`) AS Increment_2020
FROM recy_ratio_europe
ORDER BY (Increment_2012 + Increment_2013 + Increment_2014 + Increment_2015 + Increment_2016 + Increment_2017 + Increment_2018 + Increment_2019 + Increment_2020) DESC
LIMIT 3
'''
pd.read_sql_query (query, engine)
# Out:
#          Country  Increment_2012  Increment_2013  Increment_2014
# 0          Malta             4.1            27.8           -17.9  \
# 1  Liechtenstein             4.4            -0.4             0.2
# 2        Finland             2.4            -1.6             3.6
#
#    Increment_2015  Increment_2016  Increment_2017  Increment_2018
# 0           -10.9             9.2            -0.9            12.8  \
# 1            10.1             4.0            -2.6             3.1
# 2            10.4             3.0             1.5            -0.1
#
#    Increment_2019  Increment_2020
# 0             2.5            18.6
# 1             5.1             3.7
# 2            -0.1             7.2

# %%
query='''
SELECT
    Country,
    ((`2012` - `2011`) / `2011` * 100) AS Increment_2012,
    ((`2013` - `2012`) / `2012` * 100) AS Increment_2013,
    ((`2014` - `2013`) / `2013` * 100) AS Increment_2014,
    ((`2015` - `2014`) / `2014` * 100) AS Increment_2015,
    ((`2016` - `2015`) / `2015` * 100) AS Increment_2016,
    ((`2017` - `2016`) / `2016` * 100) AS Increment_2017,
    ((`2018` - `2017`) / `2017` * 100) AS Increment_2018,
    ((`2019` - `2018`) / `2018` * 100) AS Increment_2019,
    ((`2020` - `2019`) / `2019` * 100) AS Increment_2020
FROM recy_ratio_europe
ORDER BY (Increment_2012 + Increment_2013 + Increment_2014 + Increment_2015 + Increment_2016 + Increment_2017 + Increment_2018 + Increment_2019 + Increment_2020) DESC
LIMIT 3
'''
pd.read_sql_query (query, engine)
# Out:
#          Country  Increment_2012  Increment_2013  Increment_2014
# 0  Liechtenstein      169.230769       -5.714286        3.030303  \
# 1          Malta       23.837209      130.516432      -36.456212
# 2         Latvia        4.347826        2.083333       48.571429
#
#    Increment_2015  Increment_2016  Increment_2017  Increment_2018
# 0      148.529412       23.668639      -12.440191       16.939891  \
# 1      -34.935897       45.320197       -3.050847       44.755245
# 2       -3.021978        5.382436       -1.612903       -2.185792
#
#    Increment_2019  Increment_2020
# 0       23.831776       13.962264
# 1        6.038647       42.369021
# 2       -1.117318        1.412429

# %% [markdown]
# Who is the recycling lider year over year?

# %%
query = '''
SELECT
    '2011' AS YEAR,
    COUNTRY,
    `2011` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2011` = (SELECT MAX(`2011`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2012' AS YEAR,
    COUNTRY,
    `2012` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2012` = (SELECT MAX(`2012`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2013' AS YEAR,
    COUNTRY,
    `2013` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2013`=(SELECT MAX(`2013`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2014' AS YEAR,
    COUNTRY,
    `2014` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2014`=(SELECT MAX(`2014`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2015' AS YEAR,
    COUNTRY,
    `2015` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2015`=(SELECT MAX(`2015`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL
    
SELECT
    '2016' AS YEAR,
    COUNTRY,
    `2016` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2016`=(SELECT MAX(`2016`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'

UNION ALL

SELECT
    '2017' AS YEAR,
    COUNTRY,
    `2017` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2017`=(SELECT MAX(`2017`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'

UNION ALL

SELECT
    '2018' AS YEAR,
    COUNTRY,
    `2018` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2018`=(SELECT MAX(`2018`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2019' AS YEAR,
    COUNTRY,
    `2019` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2019`=(SELECT MAX(`2019`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
    
UNION ALL

SELECT
    '2020' AS YEAR,
    COUNTRY,
    `2020` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    `2020`=(SELECT MAX(`2020`) FROM recy_ratio_europe WHERE Material = 'Packaging')
    AND Material = 'Packaging'
'''
pd.read_sql_query(query, engine)
# Out:
#    YEAR  COUNTRY  Recycling_Ratio   Material
# 0  2011  Belgium             80.2  Packaging
# 1  2012  Belgium             80.3  Packaging
# 2  2013  Belgium             78.7  Packaging
# 3  2014  Belgium             81.3  Packaging
# 4  2015  Belgium             81.5  Packaging
# 5  2016  Belgium             81.9  Packaging
# 6  2017  Belgium             83.8  Packaging
# 7  2018  Belgium             85.3  Packaging
# 8  2019  Belgium             83.5  Packaging
# 9  2020  Belgium             79.7  Packaging

# %%
query = '''
SELECT
    '2011' AS YEAR,
    COUNTRY,
    `2011` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2011` = (SELECT MAX(`2011`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2012' AS YEAR,
    COUNTRY,
    `2012` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2012` = (SELECT MAX(`2012`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2013' AS YEAR,
    COUNTRY,
    `2013` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2013` = (SELECT MAX(`2013`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2014' AS YEAR,
    COUNTRY,
    `2014` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2014` = (SELECT MAX(`2014`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2015' AS YEAR,
    COUNTRY,
    `2015` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2015` = (SELECT MAX(`2015`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL
    
SELECT
    '2016' AS YEAR,
    COUNTRY,
    `2016` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2016` = (SELECT MAX(`2016`) FROM recy_ratio_europe WHERE Material <> 'Packaging')

UNION ALL

SELECT
    '2017' AS YEAR,
    COUNTRY,
    `2017` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2017` = (SELECT MAX(`2017`) FROM recy_ratio_europe WHERE Material <> 'Packaging')

UNION ALL

SELECT
    '2018' AS YEAR,
    COUNTRY,
    `2018` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2018` = (SELECT MAX(`2018`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2019' AS YEAR,
    COUNTRY,
    `2019` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
    AND `2019` = (SELECT MAX(`2019`) FROM recy_ratio_europe WHERE Material <> 'Packaging')
    
UNION ALL

SELECT
    '2020' AS YEAR,
    COUNTRY,
    `2020` AS Recycling_Ratio,
    Material
FROM
    recy_ratio_europe
WHERE
    Material <> 'Packaging'
   
'''
pd.read_sql_query(query, engine)
# Out:
#     YEAR        COUNTRY  Recycling_Ratio         Material
# 0   2011        Belgium            100.0            Glass
# 1   2012        Belgium            100.0            Glass
# 2   2013        Belgium            100.0            Glass
# 3   2014        Finland            101.2  Cardboard_paper
# 4   2015        Finland            111.6  Cardboard_paper
# ..   ...            ...              ...              ...
# 82  2020       Slovakia             74.4            Glass
# 83  2020        Finland             97.3            Glass
# 84  2020         Sweden             93.5            Glass
# 85  2020  Liechtenstein             79.9            Glass
# 86  2020         Norway             90.4            Glass
#
# [87 rows x 4 columns]

# %% [markdown]
# What is the material more generated?

# %% [markdown]
# which is the most frequent garbagge recollected in Spain and where?

# %%
query='''
SELECT YEAR, REGION, MAX(`COLLECTED KG`) AS MAX_COLLECTED_KG, `GARBAGE CONTAINER` AS MATERIAL
FROM final_collected_spain1
GROUP BY YEAR, REGION, `GARBAGE CONTAINER`
ORDER BY MAX_COLLECTED_KG DESC
LIMIT 10
'''
pd.read_sql_query (query, engine)
# Out:
#    YEAR     REGION  MAX_COLLECTED_KG MATERIAL
# 0  2008  CATALUÃ‘A         217789188     Blue
# 1  2007  CATALUÃ‘A         214719347     Blue
# 2  2009  CATALUÃ‘A         202624839     Blue
# 3  2006  CATALUÃ‘A         192569829     Blue
# 4  2005  CATALUÃ‘A         171654272     Blue
# 5  2008     MADRID         147688212     Blue
# 6  2009     MADRID         147575088     Blue
# 7  2007     MADRID         139061399     Blue
# 8  2004  CATALUÃ‘A         136419812     Blue
# 9  2003  CATALUÃ‘A         132121948     Blue

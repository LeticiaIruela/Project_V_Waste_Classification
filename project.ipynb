# %%
import pandas as pd 
import numpy as np
import os

# %%
https://www.kaggle.com/code/thiagopanini/predicting-the-success-of-a-restaurant
# Out:
#   Cell In[48], line 1
#     https://www.kaggle.com/code/thiagopanini/predicting-the-success-of-a-restaurant
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# OPTIMIZACION DE COSTES: PAC

# %% [markdown]
# https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis?select=DataCoSupplyChainDataset.csv
#
# ML predicción de NPs su riesgo de late delivery en función de sus caracteristicas? Si alto riesgo, hacer recomendacion de un producto similar. Supervisado.
# Recomendación de productos:  filtrado colaborativo o basado en contenido para recomendar productos a los clientes en función de su historial de compras, datos demográficos y características de los productos. Supervisado.
#
# Hacer un blocker según el tipo de producto, precio, tipo de pago para saber si puede ser o no fraude. Según el tipo de transacción, la logística de envío, el rendimiento, los detalles del cliente y los atributos del producto puede haber patrones anomalos de comportamiento que puedan predecir fraude  NO supervisado. Al aplicar técnicas de aprendizaje no supervisado, como el clustering o los métodos de detección de anomalías, podrías descubrir patrones o comportamientos inusuales en estas variables, lo que podría indicar transacciones fraudulentas, eventos inusuales o desviaciones
#
# Análisis y predicción de ruptura de stock para mejorar el aprovisionamiento. Deemanda histórica, los patrones estacionales, las tendencias del mercado, los tiempos de entrega, etcétera

# %%
https://www.kaggle.com/code/thiagopanini/predicting-the-success-of-a-restaurant

# %% [markdown]
# Fraud https://www.kaggle.com/code/jaswanthhbadvelu/comparison-of-ml-models-with-rnn

# %% [markdown]
# Analisis https://www.kaggle.com/code/cheukhangtse/dataco-supply-chain-analysis#Engaging-with-Potential-Clients-

# %% [markdown]
# Purchasing intention https://www.kaggle.com/code/vigneshprakash/online-shoppers-purchasing-intention-pca-smote#Multicollinearity

# %%
df1 = pd.read_csv('DataCoSupplyChainDataset.csv', encoding='latin-1')
df1
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)
# 0          DEBIT                         3                              4  \
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status
# ...

# %%
df1.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df1['Delivery Status'].unique()
# Out:
# array(['Advance shipping', 'Late delivery', 'Shipping on time',
#        'Shipping canceled'], dtype=object)

# %%
fraud_count = df1['Delivery Status'].value_counts()['Shipping on time']
fraud_count
# Out:
# 32196

# %%
ids = df1['Customer Id'].value_counts()
ids
# Out:
# Customer Id
# 5654     47
# 10591    45
# 5004     45
# 5715     44
# 3708     44
#          ..
# 18698     1
# 15537     1
# 15484     1
# 20681     1
# 2677      1
# Name: count, Length: 20652, dtype: int64

# %%
df1['Product Name'].nunique()
# Out:
# 118

# %%
df1.shape
# Out:
# (180519, 53)

# %%
df3 = pd.read_csv('6M-0K-99K.users.dataset.public.csv', encoding='latin-1')
df3
# Out:
#             identifierHash  type      country language  socialNbFollowers
# 0     -1097895247965112460  user  Royaume-Uni       en                147  \
# 1      2347567364561867620  user       Monaco       en                167
# 2      6870940546848049750  user       France       fr                137
# 3     -4640272621319568052  user   Etats-Unis       en                131
# 4     -5175830994878542658  user   Etats-Unis       en                167
# ...                    ...   ...          ...      ...                ...
# 98908 -5324380437900495747  user   Etats-Unis       fr                  3
# 98909 -5607668753771114442  user       France       fr                  3
# 98910   350630276238833248  user     Belgique       en                  3
# 98911  2006580738726207028  user       Italie       it                  3
# 98912 -7621316584087253691  user      GuinÃ©e       fr                  3
#
#        socialNbFollows  socialProductsLiked  productsListed  productsSold
# ...

# %%
df3.columns
# Out:
# Index(['identifierHash', 'type', 'country', 'language', 'socialNbFollowers',
#        'socialNbFollows', 'socialProductsLiked', 'productsListed',
#        'productsSold', 'productsPassRate', 'productsWished', 'productsBought',
#        'gender', 'civilityGenderId', 'civilityTitle', 'hasAnyApp',
#        'hasAndroidApp', 'hasIosApp', 'hasProfilePicture', 'daysSinceLastLogin',
#        'seniority', 'seniorityAsMonths', 'seniorityAsYears', 'countryCode'],
#       dtype='object')

# %% [markdown]
# https://www.kaggle.com/datasets/harshsingh2209/supply-chain-analysis

# %%
df2 = pd.read_csv('supply_chain_data.csv', encoding='latin-1')
df2
# Out:
#    Product type    SKU      Price  Availability  Number of products sold
# 0      haircare   SKU0  69.808006            55                      802  \
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times
# ...

# %%
df2.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df2['Defect rates'].unique()
# Out:
# array([0.22641036, 4.85406803, 4.58059262, 4.74664862, 3.14557952,
#        2.77919351, 1.00091062, 0.39817719, 2.70986269, 3.84461448,
#        1.72731393, 0.02116982, 2.16125375, 1.63107423, 0.10068285,
#        2.26440576, 1.01256309, 0.10202075, 2.23193911, 3.64645087,
#        4.23141657, 0.01860757, 2.59127547, 1.34229156, 3.69131029,
#        3.79723122, 2.11931974, 2.86466784, 0.81575708, 3.87809894,
#        0.96539471, 2.98900001, 1.94603612, 3.54104601, 0.64660456,
#        0.5411541 , 3.80553338, 2.61028808, 0.6133269 , 1.4519722 ,
#        4.21326943, 0.04530226, 4.93925529, 0.37230477, 2.96262632,
#        3.21960461, 3.64861059, 0.38057359, 1.69811254, 2.82581399,
#        4.7548008 , 1.77295117, 2.12247162, 1.41034758, 2.47877198,
#        4.54891966, 1.1737555 , 2.51117483, 1.73037472, 0.44719402,
#        2.85309062, 4.36747054, 1.8740014 , 3.63284329, 0.15948631,
#        4.91109595, 3.44806329, 0.13195544, 1.98346787, 1.36238799,
# ...

# %%
df2['Inspection results'].unique()
# Out:
# array(['Pending', 'Fail', 'Pass'], dtype=object)

# %%
fraud_count = df2['Inspection results'].value_counts()['Pass']
fraud_count
# Out:
# 23

# %% [markdown]
# https://www.kaggle.com/datasets/laurinbrechter/supply-chain-data

# %%
df3 = pd.read_excel('Supply2.xlsx')
df3
# Out:
#           Order ID Order Date Origin Port Carrier  TPT Service Level
# 0     1.447296e+09 2013-05-26      PORT09   V44_3    1           CRF  \
# 1     1.447158e+09 2013-05-26      PORT09   V44_3    1           CRF
# 2     1.447139e+09 2013-05-26      PORT09   V44_3    1           CRF
# 3     1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
# 4     1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
# ...            ...        ...         ...     ...  ...           ...
# 9210  1.447305e+09 2013-05-26      PORT04  V444_1    1           DTD
# 9211  1.447319e+09 2013-05-26      PORT04  V444_1    1           DTD
# 9212  1.447322e+09 2013-05-26      PORT04  V444_1    1           DTD
# 9213  1.447145e+09 2013-05-26      PORT04  V444_1    1           DTD
# 9214  1.447328e+09 2013-05-26      PORT04  V444_1    1           DTD
#
#       Ship ahead day count  Ship Late Day count           Customer
# 0                        3                    0          V55555_53  \
# ...

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import re
import numpy as np

# %%
def drop_columns_without_name(df):
    columns_without_name = df.columns[df.columns.map(lambda x: isinstance(x, float))]
    df = df.drop(columns_without_name, axis=1)
    return df

# %%
def rename_columns_and_drop_rows(df):
    rename_names = df.iloc[7].tolist()
    df.columns = rename_names
    df.drop(range(0, 9), axis=0, inplace=True)
    return df

# %%
def generated_rename_columns_and_drop_rows(df):
    rename_names = df.iloc[8].tolist()
    df.columns = rename_names
    df.drop(range(0, 10), axis=0, inplace=True)
    return df

# %%
def drop_columns_without_name(df):
    columns_without_name = df.columns[df.columns.map(lambda x: isinstance(x, float))]
    df = df.drop(columns_without_name, axis=1)
    return df

# %%
def drop_rows_with_colon(df):
    df = df[~df.astype(str).apply(lambda row: row.str.contains(":", na=False)).any(axis=1)]
    return df

# %%
def concat_dataframes(df1, df2, df3=None, df4=None, df5=None):
    dfs = [df1, df2]

    if df3 is not None:
        dfs.append(df3)
    if df4 is not None:
        dfs.append(df4)
    if df5 is not None:
        dfs.append(df5)

    df = pd.concat(dfs, axis=0)
    return df

# %%
def drop_rows_with_nan(df):
    df = df.dropna(axis=0, how='any')
    return df

# %%
def rename_columns(df, new_names):
    df = df.rename(columns=new_names)
    return df

# %%
def rename_columns_and_drop_rows(df):
    rename_names = df.iloc[7].tolist()
    df.columns = rename_names
    df.drop(range(0, 9), axis=0, inplace=True)
    return df

# %%
def drop_rows(df, column, values):
    df = df.dropna()
    df = df[~df[column].isin(values)]
    return df

# %% [markdown]
# #  Europe - waste generated

# %%
excel_file = pd.ExcelFile('datasets/env_waspac__custom_6440450_page_spreadsheet.xlsx')

# %%
sheet_names = excel_file.sheet_names
dfs={}
for sheet_name in sheet_names:
    df=excel_file.parse(sheet_name)
    dfs[sheet_name]=df

# %%
df_generated_global_packaging=dfs['Sheet 1']

# %%
df_generated_global_packaging = generated_rename_columns_and_drop_rows(df_generated_global_packaging)
df_generated_global_packaging.head()
# Out:
#                                          TIME    2011  NaN    2012  NaN
# 10  European Union - 27 countries (from 2020)  157.15    s  154.77  NaN  \
# 11                                    Belgium  154.24  NaN  154.46  NaN
# 12                                   Bulgaria   42.82  NaN      45  NaN
# 13                                    Czechia   90.06  NaN   91.56  NaN
# 14                                    Denmark  158.53   be  160.05    e
#
#       2013 NaN    2014 NaN    2015  ...    2016 NaN    2017  NaN    2018  NaN
# 10  156.57 NaN  161.18 NaN  165.16  ...  168.96 NaN  173.84  NaN  173.25  NaN  \
# 11  155.77 NaN   155.4 NaN  155.32  ...  157.13 NaN  156.55  NaN  157.51  NaN
# 12   48.18 NaN   52.42 NaN   54.69  ...   59.08 NaN   64.05  NaN   70.82  NaN
# 13   95.66 NaN   96.89 NaN  103.14  ...  108.82 NaN  115.03  NaN     122  NaN
# 14  159.05 NaN  161.41 NaN  155.26  ...  163.29 NaN  168.29  NaN   173.1  NaN
#
#       2019  NaN    2020  NaN
# 10  177.56  NaN  177.92    s
# 11  160.62  NaN  167.28  NaN
# 12   79.49  NaN       :  NaN
# 13  125.04  NaN  124.21  NaN
# 14  169.11  NaN  179.34  NaN
#
# [5 rows x 21 columns]

# %%
df_generated_global_packaging = drop_columns_without_name(df_generated_global_packaging)

# %%
df_generated_global_packaging = drop_columns_without_name(df_generated_global_packaging)

# %%
df_generated_global_packaging=drop_rows_with_colon(df_generated_global_packaging)
df_generated_global_packaging=drop_rows_with_nan(df_generated_global_packaging)

# %%
new_names5 = {'TIME': 'COUNTRY'}
df_generated_global_packaging = rename_columns(df_generated_global_packaging, new_names5)
df_generated_global_packaging.head()
# Out:
#                                              COUNTRY    2011    2012    2013
# 10         European Union - 27 countries (from 2020)  157.15  154.77  156.57  \
# 11                                           Belgium  154.24  154.46  155.77
# 13                                           Czechia   90.06   91.56   95.66
# 14                                           Denmark  158.53  160.05  159.05
# 15  Germany (until 1990 former territory of the FRG)  205.37  206.23  212.37
#
#       2014    2015    2016    2017    2018    2019    2020
# 10  161.18  165.16  168.96  173.84  173.25  177.56  177.92
# 11   155.4  155.32  157.13  156.55  157.51  160.62  167.28
# 13   96.89  103.14  108.82  115.03     122  125.04  124.21
# 14  161.41  155.26  163.29  168.29   173.1  169.11  179.34
# 15  219.53  222.23  220.55  226.52  227.49  227.55  225.79

# %%
df_generated_global_packaging.to_excel('datasets/df_generated_global_packaging.xlsx', index=True)

# %%
df_generated_global_packaging.to_csv('datasets/df_generated_global_packaging.csv')

# %% [markdown]
# ### QUERY

# %% [markdown]
# ### 3.1 Connection to SQL

# %% [markdown]
# Establish connection to MySQL Workbench

# %%
import os
from dotenv import load_dotenv
import sqlalchemy as alch
import src.sql_queries as sql
import pymysql
import sqlalchemy as alch # python -m pip install --upgrade 'sqlalchemy<2.0'
from getpass import getpass
import pandas as pd
import src.sql_queries as sql

# %%
def connection_sql(password, dbName):
    load_dotenv()
    connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
    engine = alch.create_engine(connectionData)
    return engine

# %%
password = os.getenv("password")

# %%
engine=sql.sql_connection("project_v")

# %%
query='''
SELECT COUNTRY, 
       SUM(`2011`) AS total_2011,
       SUM(`2012`) AS total_2012,
       SUM(`2013`) AS total_2013,
       SUM(`2014`) AS total_2014,
       SUM(`2015`) AS total_2015,
       SUM(`2016`) AS total_2016,
       SUM(`2017`) AS total_2017,
       SUM(`2018`) AS total_2018,
       SUM(`2019`) AS total_2019,
       SUM(`2020`) AS total_2020
FROM df_generated_global_packaging
GROUP BY COUNTRY
'''
pd.read_sql_query (query, engine)
# Out:
#                                              COUNTRY  total_2011  total_2012
# 0          European Union - 27 countries (from 2020)      157.15      154.77  \
# 1                                            Belgium      154.24      154.46
# 2                                            Czechia       90.06       91.56
# 3                                            Denmark      158.53      160.05
# 4   Germany (until 1990 former territory of the FRG)      205.37      206.23
# 5                                            Estonia      145.41      149.15
# 6                                            Ireland      188.55      176.00
# 7                                              Spain      152.90      143.73
# 8                                             France      196.70      187.30
# 9                                              Italy      195.99      190.55
# 10                                            Cyprus       88.80       86.75
# 11                                            Latvia      104.91      105.13
# 12                                         Lithuania       96.54      101.12
# 13                                        Luxembourg      201.95      202.67
# 14                                           Hungary       84.08      102.10
# 15                                             Malta      127.93      125.12
# 16                                       Netherlands      164.62      164.07
# 17                                           Austria      146.82      148.70
# 18                                          Portugal      148.31      145.34
# 19                                           Romania       49.26       52.82
# 20                                          Slovenia      101.03       98.20
# 21                                          Slovakia       82.19       82.91
# 22                                           Finland      131.70      132.20
# 23                                            Sweden      109.13      111.17
# 24                                           Iceland      138.52      139.00
# 25                                     Liechtenstein      157.63      141.72
# 26                                            Norway      146.69      138.76
#
#     total_2013  total_2014  total_2015  total_2016  total_2017  total_2018
# 0       156.57      161.18      165.16      168.96      173.84      173.25  \
# 1       155.77      155.40      155.32      157.13      156.55      157.51
# 2        95.66       96.89      103.14      108.82      115.03      122.00
# 3       159.05      161.41      155.26      163.29      168.29      173.10
# 4       212.37      219.53      222.23      220.55      226.52      227.49
# 5       169.90      173.30      172.14      169.33      175.46      158.15
# 6       188.18      208.13      209.14      208.46      215.98      208.06
# 7       143.63      147.64      154.03      155.55      161.70      161.22
# 8       184.43      188.10      187.36      190.08      193.08      195.49
# 9       190.31      196.78      202.82      209.54      217.35      211.20
# 10       91.31       85.69       85.97       86.23       89.94       86.73
# 11      113.94      111.15      118.00      118.20      122.17      133.54
# 12      108.11      117.56      120.94      127.39      127.72      126.58
# 13      206.14      227.03      217.55      222.44      225.15      224.04
# 14      103.34      110.01      117.68      121.78      128.82      138.35
# 15      133.89      133.76      140.64      146.98      146.76      146.65
# 16      167.46      165.25      182.00      184.38      183.17      165.05
# 17      149.97      152.52      151.72      153.46      156.52      159.90
# 18      149.10      151.46      153.05      160.18      166.01      173.47
# 19       52.75       62.52       70.48       68.53       71.92       80.47
# 20       97.28      101.70      104.75      108.04      113.29      114.81
# 21       81.77       85.56       90.94       95.35       95.15      102.20
# 22      131.77      134.01      130.27      129.19      135.00      127.93
# 23      109.17      113.23      113.34      132.41      130.75      133.04
# 24      147.59      129.39      140.88      147.12      150.40      146.79
# 25      152.28      155.15      172.83      165.74      169.88      174.66
# 26      145.68      148.53      153.03      149.53      163.05      161.11
#
#     total_2019  total_2020
# 0       177.56      177.92
# 1       160.62      167.28
# 2       125.04      124.21
# 3       169.11      179.34
# 4       227.55      225.79
# 5       157.64      154.74
# 6       227.98      224.45
# 7       170.04      168.21
# 8       187.01      187.60
# 9       215.64      208.77
# 10       92.31       91.68
# 11      136.74      142.81
# 12      134.41      136.79
# 13      217.22      205.22
# 14      142.79      154.61
# 15      153.70      139.81
# 16      170.42      173.55
# 17      161.89      157.34
# 18      172.22      175.07
# 19      103.81      116.38
# 20      117.44      118.16
# 21      104.77      103.67
# 22      131.44      157.66
# 23      134.31      132.06
# 24      149.05      130.61
# 25      178.39      195.49
# 26      165.51      173.45

# %%
df_generated_global_packaging.to_sql('df_generated_global_packaging', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:3366, in Engine._wrap_pool_connect(self, fn, connection)
#    3365 try:
# -> 3366     return fn()
#    3367 except dialect.dbapi.Error as e:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:493, in _ConnectionRecord.checkout(cls, pool)
#     491 @classmethod
#     492 def checkout(cls, pool):
# --> 493     rec = pool._do_get()
#     494     try:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\impl.py:145, in QueuePool._do_get(self)
#     144 except:
# --> 145     with util.safe_reraise():
#     146         self._dec_overflow()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:273, in Pool._create_connection(self)
#     271 """Called by subclasses to create a new ConnectionRecord."""
# --> 273 return _ConnectionRecord(self)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:388, in _ConnectionRecord.__init__(self, pool, connect)
#     387 if connect:
# --> 388     self.__connect()
#     389 self.finalize_callback = deque()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:690, in _ConnectionRecord.__connect(self)
#     689 except BaseException as e:
# --> 690     with util.safe_reraise():
#     691         pool.logger.debug("Error on connect(): %s", e)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:686, in _ConnectionRecord.__connect(self)
#     685 self.starttime = time.time()
# --> 686 self.dbapi_connection = connection = pool._invoke_creator(self)
#     687 pool.logger.debug("Created new connection %r", connection)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\create.py:574, in create_engine.<locals>.connect(connection_record)
#     573             return connection
# --> 574 return dialect.connect(*cargs, **cparams)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351 else:
# --> 352     self.connect()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:636, in Connection.connect(self, sock)
#     635 self._get_server_information()
# --> 636 self._request_authentication()
#     638 if self.sql_mode is not None:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:933, in Connection._request_authentication(self)
#     932 if self._auth_plugin_name == "caching_sha2_password":
# --> 933     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     934 elif self._auth_plugin_name == "sha256_password":
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\_auth.py:266, in caching_sha2_password_auth(conn, pkt)
#     265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266 pkt = _roundtrip(conn, data)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\_auth.py:120, in _roundtrip(conn, send_data)
#     119 conn.write_packet(send_data)
# --> 120 pkt = conn._read_packet()
#     121 pkt.check_error()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df_generated_global_packaging.to_sql('df_generated_global_packaging', con=engine, if_exists='replace', index=False)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:766, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     761 elif not isinstance(frame, DataFrame):
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
# --> 766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#    (...)
#     778         **engine_kwargs,
#     779     )
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:830, in pandasSQL_builder(con, schema, need_transaction)
#     827     raise ImportError("Using URI string without sqlalchemy installed.")
#     829 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 830     return SQLDatabase(con, schema, need_transaction)
#     832 warnings.warn(
#     833     "pandas only supports SQLAlchemy connectable (engine/connection) or "
#     834     "database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 "
#    (...)
#     837     stacklevel=find_stack_level(),
#     838 )
#     839 return SQLiteDatabase(con)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pandas\io\sql.py:1537, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1535     self.exit_stack.callback(con.dispose)
#    1536 if isinstance(con, Engine):
# -> 1537     con = self.exit_stack.enter_context(con.connect())
#    1538 if need_transaction and not con.in_transaction():
#    1539     self.exit_stack.enter_context(con.begin())
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:3320, in Engine.connect(self, close_with_result)
#    3305 def connect(self, close_with_result=False):
#    3306     """Return a new :class:`_engine.Connection` object.
#    3307
#    3308     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3317
#    3318     """
# -> 3320     return self._connection_cls(self, close_with_result=close_with_result)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:3399, in Engine.raw_connection(self, _connection)
#    3377 def raw_connection(self, _connection=None):
#    3378     """Return a "raw" DBAPI connection from the connection pool.
#    3379
#    3380     The returned object is a proxied version of the DBAPI
#    (...)
#    3397
#    3398     """
# -> 3399     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:3369, in Engine._wrap_pool_connect(self, fn, connection)
#    3367 except dialect.dbapi.Error as e:
#    3368     if connection is None:
# -> 3369         Connection._handle_dbapi_exception_noconnection(
#    3370             e, dialect, self
#    3371         )
#    3372     else:
#    3373         util.raise_(
#    3374             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3375         )
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:2203, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2201     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2202 elif should_wrap:
# -> 2203     util.raise_(
#    2204         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2205     )
#    2206 else:
#    2207     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\base.py:3366, in Engine._wrap_pool_connect(self, fn, connection)
#    3364 dialect = self.dialect
#    3365 try:
# -> 3366     return fn()
#    3367 except dialect.dbapi.Error as e:
#    3368     if connection is None:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:327, in Pool.connect(self)
#     319 def connect(self):
#     320     """Return a DBAPI connection from the pool.
#     321
#     322     The connection is instrumented such that when its
#    (...)
#     325
#     326     """
# --> 327     return _ConnectionFairy._checkout(self)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     891 @classmethod
#     892 def _checkout(cls, pool, threadconns=None, fairy=None):
#     893     if not fairy:
# --> 894         fairy = _ConnectionRecord.checkout(pool)
#     896         fairy._pool = pool
#     897         fairy._counter = 0
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:493, in _ConnectionRecord.checkout(cls, pool)
#     491 @classmethod
#     492 def checkout(cls, pool):
# --> 493     rec = pool._do_get()
#     494     try:
#     495         dbapi_connection = rec.get_connection()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:273, in Pool._create_connection(self)
#     270 def _create_connection(self):
#     271     """Called by subclasses to create a new ConnectionRecord."""
# --> 273     return _ConnectionRecord(self)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:388, in _ConnectionRecord.__init__(self, pool, connect)
#     386 self.__pool = pool
#     387 if connect:
# --> 388     self.__connect()
#     389 self.finalize_callback = deque()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:690, in _ConnectionRecord.__connect(self)
#     688     self.fresh = True
#     689 except BaseException as e:
# --> 690     with util.safe_reraise():
#     691         pool.logger.debug("Error on connect(): %s", e)
#     692 else:
#     693     # in SQLAlchemy 1.4 the first_connect event is not used by
#     694     # the engine, so this will usually not be set
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\pool\base.py:686, in _ConnectionRecord.__connect(self)
#     684 try:
#     685     self.starttime = time.time()
# --> 686     self.dbapi_connection = connection = pool._invoke_creator(self)
#     687     pool.logger.debug("Created new connection %r", connection)
#     688     self.fresh = True
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\create.py:574, in create_engine.<locals>.connect(connection_record)
#     572         if connection is not None:
#     573             return connection
# --> 574 return dialect.connect(*cargs, **cparams)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\sqlalchemy\engine\default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     350     self._sock = None
#     351 else:
# --> 352     self.connect()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:636, in Connection.connect(self, sock)
#     633 self._next_seq_id = 0
#     635 self._get_server_information()
# --> 636 self._request_authentication()
#     638 if self.sql_mode is not None:
#     639     c = self.cursor()
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:933, in Connection._request_authentication(self)
#     931 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     932 if self._auth_plugin_name == "caching_sha2_password":
# --> 933     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     934 elif self._auth_plugin_name == "sha256_password":
#     935     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\_auth.py:266, in caching_sha2_password_auth(conn, pkt)
#     263         print(conn.server_public_key.decode("ascii"))
#     265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266 pkt = _roundtrip(conn, data)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\_auth.py:120, in _roundtrip(conn, send_data)
#     118 def _roundtrip(conn, send_data):
#     119     conn.write_packet(send_data)
# --> 120     pkt = conn._read_packet()
#     121     pkt.check_error()
#     122     return pkt
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File C:\Users\DataLeticia\miniconda3\envs\ironhack\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
query="SELECT * FROM df_generated_global_packaging;"
df10 = pd.read_sql(query, engine)
df10.sample()

# %% [markdown]
# - What is the total waste evolution across the years in Europe?

# %% [markdown]
# # Europe Recycled ratio

# %%
excel_file = pd.ExcelFile('datasets/eurostat.xlsx')

# %%
def remove_columns(df, col):
    df = df.drop(columns=col)
    return df

# %%
def clean_data(df):
    df.drop_duplicates(inplace=True)
    return df

# %%
sheet_names = excel_file.sheet_names
dfs={}
for sheet_name in sheet_names:
    df=excel_file.parse(sheet_name)
    dfs[sheet_name]=df

# %%
df_packaging = dfs['Sheet 1']
df_cardboard_paper = dfs['Sheet 2']
df_plastic = dfs['Sheet 3']
df_glass = dfs['Sheet 6']

# %%
df_packaging = rename_columns_and_drop_rows(df_packaging)
df_packaging.head()
# Out:
#                                          TIME  2009  NaN  2010  NaN  2011
# 9   European Union - 27 countries (from 2020)  62.6    s    64    s  64.2  \
# 10       Euro area – 20 countries (from 2023)     :  NaN     :  NaN     :
# 11      Euro area - 19 countries  (2015-2022)     :  NaN     :  NaN     :
# 12                                    Belgium  79.1  NaN  79.8  NaN  80.2
# 13                                   Bulgaria  45.9  NaN  61.6  NaN  65.1
#
#     NaN  2012  NaN  2013  ...  2016 NaN  2017  NaN  2018  NaN  2019  NaN
# 9     s  65.2  NaN  65.4  ...  67.6 NaN  67.5  NaN  65.6  NaN  64.6  NaN  \
# 10  NaN     :  NaN     :  ...     : NaN     :  NaN     :  NaN     :  NaN
# 11  NaN     :  NaN     :  ...     : NaN     :  NaN     :  NaN     :  NaN
# 12  NaN  80.3  NaN  78.7  ...  81.9 NaN  83.8  NaN  85.3  NaN  83.5  NaN
# 13  NaN  66.5  NaN  65.7  ...  63.8 NaN  65.6  NaN  60.4  NaN  61.2  NaN
#
#     2020  NaN
# 9     64    s
# 10     :  NaN
# 11     :  NaN
# 12  79.7  NaN
# 13     :  NaN
#
# [5 rows x 25 columns]

# %%
df_packaging = drop_columns_without_name(df_packaging)
df_packaging.sample()
# Out:
#              TIME 2009 2010 2011 2012 2013  NaN 2014  NaN 2015  NaN 2016  NaN
# 50  Special value  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
#
#    2017 2018 2019 2020
# 50  NaN  NaN  NaN  NaN

# %%
df_packaging=drop_columns_without_name(df_packaging)
df_packaging.head()
# Out:
#                                          TIME  2009  2010  2011  2012  2013
# 9   European Union - 27 countries (from 2020)  62.6    64  64.2  65.2  65.4  \
# 10       Euro area – 20 countries (from 2023)     :     :     :     :     :
# 11      Euro area - 19 countries  (2015-2022)     :     :     :     :     :
# 12                                    Belgium  79.1  79.8  80.2  80.3  78.7
# 13                                   Bulgaria  45.9  61.6  65.1  66.5  65.7
#
#     2014  2015  2016  2017  2018  2019  2020
# 9   66.5  66.6  67.6  67.5  65.6  64.6    64
# 10     :     :     :     :     :     :     :
# 11     :     :     :     :     :     :     :
# 12  81.3  81.5  81.9  83.8  85.3  83.5  79.7
# 13    62  64.1  63.8  65.6  60.4  61.2     :

# %%
df_packaging=drop_rows_with_colon(df_packaging)
df_packaging.head()
# Out:
#                                                 TIME  2009  2010  2011  2012
# 9          European Union - 27 countries (from 2020)  62.6    64  64.2  65.2  \
# 12                                           Belgium  79.1  79.8  80.2  80.3
# 14                                           Czechia  68.8    70  69.7  69.9
# 15                                           Denmark    84    84  54.3  61.6
# 16  Germany (until 1990 former territory of the FRG)  73.5  72.7  71.8  71.3
#
#     2013  2014  2015  2016  2017  2018  2019  2020
# 9   65.4  66.5  66.6  67.6  67.5  65.6  64.6    64
# 12  78.7  81.3  81.5  81.9  83.8  85.3  83.5  79.7
# 14  69.9    73  74.3  75.3  72.3  69.6  71.2  67.9
# 15  69.8  69.8  73.9    79  71.5  70.1  70.4    64
# 16  71.8  71.4  69.3  70.7  69.9  68.5  63.2  68.1

# %%
df_packaging=drop_rows_with_nan(df_packaging)
df_packaging.head()
# Out:
#                                                 TIME  2009  2010  2011  2012
# 9          European Union - 27 countries (from 2020)  62.6    64  64.2  65.2  \
# 12                                           Belgium  79.1  79.8  80.2  80.3
# 14                                           Czechia  68.8    70  69.7  69.9
# 15                                           Denmark    84    84  54.3  61.6
# 16  Germany (until 1990 former territory of the FRG)  73.5  72.7  71.8  71.3
#
#     2013  2014  2015  2016  2017  2018  2019  2020
# 9   65.4  66.5  66.6  67.6  67.5  65.6  64.6    64
# 12  78.7  81.3  81.5  81.9  83.8  85.3  83.5  79.7
# 14  69.9    73  74.3  75.3  72.3  69.6  71.2  67.9
# 15  69.8  69.8  73.9    79  71.5  70.1  70.4    64
# 16  71.8  71.4  69.3  70.7  69.9  68.5  63.2  68.1

# %%
df_cardboard_paper = rename_columns_and_drop_rows(df_cardboard_paper)
df_cardboard_paper.sample()
# Out:
#           TIME 2009  NaN 2010  NaN 2011  NaN 2012  NaN 2013  ...  2016 NaN
# 44  Montenegro    :  NaN    :  NaN    :  NaN    :  NaN    :  ...     : NaN  \
#
#     2017 NaN  2018  NaN  2019  NaN  2020  NaN
# 44     : NaN     :  NaN     :  NaN     :  NaN
#
# [1 rows x 25 columns]

# %%
df_cardboard_paper = drop_columns_without_name(df_cardboard_paper)
df_cardboard_paper.sample()
# Out:
#       TIME  2009  2010 2011  2012  2013  NaN  2014  NaN 2015  NaN  2016  NaN
# 21  France  85.6  91.9   88  91.8  95.8  NaN  94.1  NaN   92  NaN  93.9  NaN  \
#
#     2017  NaN  2018  2019  2020
# 21  98.4  NaN  92.1  91.4  82.2

# %%
df_cardboard_paper = drop_columns_without_name(df_cardboard_paper)
df_cardboard_paper.sample()
# Out:
#        TIME 2009  2010  2011  2012  2013 2014  2015  2016  2017  2018  2019
# 39  Iceland    :  65.3  76.5  62.9  71.6   76  83.9  83.1  83.7  92.9  87.2  \
#
#     2020
# 39  99.5

# %%
df_cardboard_paper=drop_rows_with_colon(df_cardboard_paper)
df_cardboard_paper.sample()
# Out:
#         TIME  2009 2010  2011  2012  2013  2014  2015  2016  2017  2018 2019
# 33  Portugal  79.5   67  71.3  66.1  73.4  69.1  62.2  70.1  66.9  66.8   71  \
#
#    2020
# 33   66

# %%
df_cardboard_paper=drop_rows_with_nan(df_cardboard_paper)
df_cardboard_paper.head()
# Out:
#                                                 TIME  2009  2010  2011  2012
# 9          European Union - 27 countries (from 2020)  83.3  83.8  82.7  83.5  \
# 12                                           Belgium    88  89.8  90.4  89.8
# 14                                           Czechia  93.9  93.5  90.5  85.9
# 15                                           Denmark  93.5  93.5  63.8  76.5
# 16  Germany (until 1990 former territory of the FRG)  91.1  90.2    88  87.6
#
#     2013  2014  2015  2016  2017  2018  2019  2020
# 9     84  84.1  83.9  85.4  85.4  84.2  82.1  81.5
# 12  89.1  90.6  90.7  89.4  92.9  95.6  92.3  89.4
# 14  87.6  88.6  90.1  93.7  90.2  85.6  88.2  87.5
# 15  85.4  91.8  95.3  97.7  81.9  99.7  99.7  69.3
# 16  88.2  87.3  85.7  88.7  87.6  86.8  80.6  84.2

# %%
df_plastic = rename_columns_and_drop_rows(df_plastic)
df_plastic.head()
# Out:
#                                          TIME  2009  NaN  2010  NaN  2011
# 9   European Union - 27 countries (from 2020)  33.5    s  34.1    s  35.6  \
# 10       Euro area – 20 countries (from 2023)     :  NaN     :  NaN     :
# 11      Euro area - 19 countries  (2015-2022)     :  NaN     :  NaN     :
# 12                                    Belgium    43  NaN  41.5  NaN  41.4
# 13                                   Bulgaria    30  NaN  40.9  NaN  39.2
#
#     NaN  2012 NaN  2013  ...  2016 NaN  2017 NaN  2018  NaN  2019  NaN  2020
# 9     s    37 NaN  37.5  ...  42.4 NaN  41.7 NaN  41.4  NaN  41.1  NaN  37.6  \
# 10  NaN     : NaN     :  ...     : NaN     : NaN     :  NaN     :  NaN     :
# 11  NaN     : NaN     :  ...     : NaN     : NaN     :  NaN     :  NaN     :
# 12  NaN  41.5 NaN    39  ...  43.4 NaN  44.5 NaN  42.4  NaN  47.3  NaN  44.7
# 13  NaN  40.7 NaN  41.3  ...  52.6 NaN  64.8 NaN  59.2  NaN  50.6  NaN     :
#
#     NaN
# 9     s
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
#
# [5 rows x 25 columns]

# %%
df_plastic = drop_columns_without_name(df_plastic)
df_plastic.head()
# Out:
#                                          TIME  2009  2010  2011  2012  NaN
# 9   European Union - 27 countries (from 2020)  33.5  34.1  35.6    37  NaN  \
# 10       Euro area – 20 countries (from 2023)     :     :     :     :  NaN
# 11      Euro area - 19 countries  (2015-2022)     :     :     :     :  NaN
# 12                                    Belgium    43  41.5  41.4  41.5  NaN
# 13                                   Bulgaria    30  40.9  39.2  40.7  NaN
#
#     2013  NaN  2014  NaN  2015  NaN  2016  NaN  2017  NaN  2018  2019  2020
# 9   37.5  NaN    39  NaN  40.5  NaN  42.4  NaN  41.7  NaN  41.4  41.1  37.6
# 10     :  NaN     :  NaN     :  NaN     :  NaN     :  NaN     :     :     :
# 11     :  NaN     :  NaN     :  NaN     :  NaN     :  NaN     :     :     :
# 12    39  NaN  41.8  NaN  42.6  NaN  43.4  NaN  44.5  NaN  42.4  47.3  44.7
# 13  41.3  NaN  64.1  NaN  60.8  NaN  52.6  NaN  64.8  NaN  59.2  50.6     :

# %%
df_plastic = drop_columns_without_name(df_plastic)
df_plastic.head()
# Out:
#                                          TIME  2009  2010  2011  2012  2013
# 9   European Union - 27 countries (from 2020)  33.5  34.1  35.6    37  37.5  \
# 10       Euro area – 20 countries (from 2023)     :     :     :     :     :
# 11      Euro area - 19 countries  (2015-2022)     :     :     :     :     :
# 12                                    Belgium    43  41.5  41.4  41.5    39
# 13                                   Bulgaria    30  40.9  39.2  40.7  41.3
#
#     2014  2015  2016  2017  2018  2019  2020
# 9     39  40.5  42.4  41.7  41.4  41.1  37.6
# 10     :     :     :     :     :     :     :
# 11     :     :     :     :     :     :     :
# 12  41.8  42.6  43.4  44.5  42.4  47.3  44.7
# 13  64.1  60.8  52.6  64.8  59.2  50.6     :

# %%
df_plastic = drop_columns_without_name(df_plastic)

# %%
df_plastic=drop_rows_with_colon(df_plastic)

# %%
df_plastic=drop_rows_with_nan(df_plastic)
df_plastic.head()
# Out:
#                                                 TIME  2009  2010  2011  2012
# 9          European Union - 27 countries (from 2020)  33.5  34.1  35.6    37  \
# 12                                           Belgium    43  41.5  41.4  41.5
# 14                                           Czechia  52.5    54    57  58.2
# 15                                           Denmark  26.4  26.4  22.3  25.9
# 16  Germany (until 1990 former territory of the FRG)  46.5  45.1  46.3    47
#
#     2013  2014  2015  2016  2017  2018  2019  2020
# 9   37.5    39  40.5  42.4  41.7  41.4  41.1  37.6
# 12    39  41.8  42.6  43.4  44.5  42.4  47.3  44.7
# 14  59.7  58.2  61.7  59.2  58.6    57    61  41.8
# 15  29.1  30.7  30.5  36.1  41.8  31.3  37.4  22.9
# 16  46.8  47.3  47.4  48.4    48  46.4  43.3  46.2

# %%
df_glass = rename_columns_and_drop_rows(df_glass)
df_glass = drop_columns_without_name(df_glass)
df_glass = drop_columns_without_name(df_glass)
df_glass=drop_rows_with_colon(df_glass)
df_glass=drop_rows_with_nan(df_glass)
df_glass.head()
# Out:
#                                                 TIME   2009   2010  2011
# 9          European Union - 27 countries (from 2020)   68.8   71.2  72.3  \
# 12                                           Belgium    100    100   100
# 14                                           Czechia   71.2   73.1  74.4
# 15                                           Denmark  174.2  174.2  85.9
# 16  Germany (until 1990 former territory of the FRG)   82.5   86.1  88.4
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020
# 9   73.1  73.4  75.3  74.2  75.3  75.8  75.8  75.6  75.9
# 12   100   100   100   100   100   100   100   100  96.9
# 14  81.1    75  71.6  72.6  72.8  72.3  74.8  76.4  83.6
# 15  93.6    93  83.6  79.5    85  94.9  82.4  71.1  84.3
# 16  84.7  88.7    89  85.2  85.5  84.4    83    78  79.7

# %%
def add_column_with_value(df, column_name, value):
    df[column_name] = value
    return df

# %%
df_glass=add_column_with_value(df_glass,'Material','Cristal')

# %%
df_cardboard_paper=add_column_with_value(df_cardboard_paper,'Material','Papel-cartón')
df_packaging=add_column_with_value(df_packaging,'Material','Packaging')
df_plastic=add_column_with_value(df_plastic,'Material','Plastic')

# %%
final_df_europe=concat_dataframes(df_cardboard_paper,df_packaging,df_plastic,df_glass)
final_df_europe.head()
# Out:
#                                                 TIME  2009  2010  2011  2012
# 9          European Union - 27 countries (from 2020)  83.3  83.8  82.7  83.5  \
# 12                                           Belgium    88  89.8  90.4  89.8
# 14                                           Czechia  93.9  93.5  90.5  85.9
# 15                                           Denmark  93.5  93.5  63.8  76.5
# 16  Germany (until 1990 former territory of the FRG)  91.1  90.2    88  87.6
#
#     2013  2014  2015  2016  2017  2018  2019  2020      Material
# 9     84  84.1  83.9  85.4  85.4  84.2  82.1  81.5  Papel-cartón
# 12  89.1  90.6  90.7  89.4  92.9  95.6  92.3  89.4  Papel-cartón
# 14  87.6  88.6  90.1  93.7  90.2  85.6  88.2  87.5  Papel-cartón
# 15  85.4  91.8  95.3  97.7  81.9  99.7  99.7  69.3  Papel-cartón
# 16  88.2  87.3  85.7  88.7  87.6  86.8  80.6  84.2  Papel-cartón

# %%
final_df_europe['Material'].unique()
# Out:
# array(['Papel-cartón', 'Packaging', 'Plastic', 'Cristal'], dtype=object)

# %%
final_df_europe.to_excel('datasets/final_df_europe.xlsx', index=True)

# %% [markdown]
# # Spain- Collected waste

# %%
excel_file = pd.ExcelFile('datasets/Recogida-2021.xlsx')

# %%
sheet_names = excel_file.sheet_names
dfs={}
for sheet_name in sheet_names:
    df=excel_file.parse(sheet_name)
    dfs[sheet_name]=df

# %%
collected_yellow_bin = dfs['BBDD Amarillo']
collected_blue_bin = dfs['BBDD Azul']
SP_bins = dfs['Contenedores']

# %%
collected_yellow_bin['KG RECOGIDOS'].unique()
# Out:
# array([2649074.,  310230.,   70260., ...,  308360.,   20440.,  589310.])

# %%
collected_blue_bin.dtypes
# Out:
# AÑO                    int64
# CCAA                  object
# UNIDAD DE GESTIÓN     object
# UG CODIGO             object
# Kg Recogidos         float64
# Nº Habitantes        float64
# dtype: object

# %%
print(type(collected_blue_bin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
def convert_INT(df, columns):
    df[columns] = df[columns].astype('int64')
    return df

# %%
collected_yellow_bin=convert_INT(collected_yellow_bin,['KG RECOGIDOS','HABITANTES'])

# %%
collected_yellow_bin.head()
# Out:
#     AÑO       CCAA                    UNIDAD DE GESTIÓN (UG) UG CODIGO
# 0  1998  ANDALUCÍA          EPREMASA (Diputación de Córdoba)       UG1  \
# 1  1998  ANDALUCÍA                                   IMUCONA     UG370
# 2  1998   ASTURIAS            Consorcio Residuos de Asturias     UG723
# 3  1998   CATALUÑA  Unidad de Gestión Genérica para Cataluña    UG1541
# 4  1998    GALICIA                        Experiencia piloto    UG1577
#
#    KG RECOGIDOS  HABITANTES
# 0       2649074      189109
# 1        310230       49152
# 2         70260      250981
# 3          6220      358403
# 4         97260      109220

# %%
print(type(collected_yellow_bin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
collected_blue_bin=convert_INT(collected_blue_bin,['Kg Recogidos','Nº Habitantes'])
collected_blue_bin.head()
# Out:
#     AÑO                CCAA UNIDAD DE GESTIÓN UG CODIGO  Kg Recogidos
# 0  1998           ANDALUCÍA               NaN       NaN       4228512  \
# 1  1998            ASTURIAS               NaN       NaN       4852620
# 2  1998            BALEARES               NaN       NaN       4129149
# 3  1998  CASTILLA-LA MANCHA               NaN       NaN        568580
# 4  1998            CATALUÑA               NaN       NaN       4362720
#
#    Nº Habitantes
# 0         600847
# 1         721222
# 2         317212
# 3         107089
# 4        4096080

# %%
def new_column(df, column_name, column_value):
    df[column_name] = column_value
    return df

# %%
collected_blue_bin = new_column(collected_blue_bin, 'CONTENEDOR', 'Azul')
collected_yellow_bin = new_column(collected_yellow_bin, 'CONTENEDOR', 'Amarillo')
collected_yellow_bin.head()
# Out:
#     AÑO       CCAA                    UNIDAD DE GESTIÓN (UG) UG CODIGO
# 0  1998  ANDALUCÍA          EPREMASA (Diputación de Córdoba)       UG1  \
# 1  1998  ANDALUCÍA                                   IMUCONA     UG370
# 2  1998   ASTURIAS            Consorcio Residuos de Asturias     UG723
# 3  1998   CATALUÑA  Unidad de Gestión Genérica para Cataluña    UG1541
# 4  1998    GALICIA                        Experiencia piloto    UG1577
#
#    KG RECOGIDOS  HABITANTES CONTENEDOR
# 0       2649074      189109   Amarillo
# 1        310230       49152   Amarillo
# 2         70260      250981   Amarillo
# 3          6220      358403   Amarillo
# 4         97260      109220   Amarillo

# %%
print(type(collected_blue_bin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_names = {'Kg Recogidos': 'KG RECOGIDOS', 'Nº Habitantes': 'HABITANTES'}
collected_blue_bin = rename_columns(collected_blue_bin, new_names)
collected_blue_bin.head()
# Out:
#     AÑO                CCAA UNIDAD DE GESTIÓN UG CODIGO  KG RECOGIDOS
# 0  1998           ANDALUCÍA               NaN       NaN       4228512  \
# 1  1998            ASTURIAS               NaN       NaN       4852620
# 2  1998            BALEARES               NaN       NaN       4129149
# 3  1998  CASTILLA-LA MANCHA               NaN       NaN        568580
# 4  1998            CATALUÑA               NaN       NaN       4362720
#
#    HABITANTES CONTENEDOR
# 0      600847       Azul
# 1      721222       Azul
# 2      317212       Azul
# 3      107089       Azul
# 4     4096080       Azul

# %%
new_names3 = {'UNIDAD DE GESTIÓN (UG)': 'UNIDAD DE GESTIÓN'}
collected_yellow_bin = rename_columns(collected_yellow_bin, new_names3)
collected_yellow_bin.head()
# Out:
#     AÑO       CCAA                         UNIDAD DE GESTIÓN UG CODIGO
# 0  1998  ANDALUCÍA          EPREMASA (Diputación de Córdoba)       UG1  \
# 1  1998  ANDALUCÍA                                   IMUCONA     UG370
# 2  1998   ASTURIAS            Consorcio Residuos de Asturias     UG723
# 3  1998   CATALUÑA  Unidad de Gestión Genérica para Cataluña    UG1541
# 4  1998    GALICIA                        Experiencia piloto    UG1577
#
#    KG RECOGIDOS  HABITANTES CONTENEDOR
# 0       2649074      189109   Amarillo
# 1        310230       49152   Amarillo
# 2         70260      250981   Amarillo
# 3          6220      358403   Amarillo
# 4         97260      109220   Amarillo

# %%
final_collected=concat_dataframes(collected_blue_bin,collected_yellow_bin)
final_collected
# Out:
#         AÑO                CCAA                          UNIDAD DE GESTIÓN
# 0      1998           ANDALUCÍA                                        NaN  \
# 1      1998            ASTURIAS                                        NaN
# 2      1998            BALEARES                                        NaN
# 3      1998  CASTILLA-LA MANCHA                                        NaN
# 4      1998            CATALUÑA                                        NaN
# ...     ...                 ...                                        ...
# 20872  2021    REGION DE MURCIA              Ayuntamiento de Torre-Pacheco
# 20873  2021    REGION DE MURCIA                     Ayuntamiento de Totana
# 20874  2021    REGION DE MURCIA                       Ayuntamiento de Ulea
# 20875  2021    REGION DE MURCIA  Ayuntamiento de Villanueva del Rio Segura
# 20876  2021    REGION DE MURCIA                      Ayuntamiento de Yecla
#
#       UG CODIGO  KG RECOGIDOS  HABITANTES CONTENEDOR
# 0           NaN       4228512      600847       Azul
# 1           NaN       4852620      721222       Azul
# 2           NaN       4129149      317212       Azul
# 3           NaN        568580      107089       Azul
# 4           NaN       4362720     4096080       Azul
# ...         ...           ...         ...        ...
# 20872    UG1222        702100       36464   Amarillo
# 20873    UG1212        308360       32529   Amarillo
# 20874    UG1762          7023         849   Amarillo
# 20875    UG1761         20440        3111   Amarillo
# 20876    UG1226        589310       34834   Amarillo
#
# [36192 rows x 7 columns]

# %%
print(type(final_collected))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
def drop_columns(df, columns_to_drop):
    df = df.drop(columns=columns_to_drop)
    return df

# %%
final_collected=drop_columns(final_collected,['UNIDAD DE GESTIÓN','UG CODIGO'])

# %%
final_collected
# Out:
#         AÑO                CCAA  KG RECOGIDOS  HABITANTES CONTENEDOR
# 0      1998           ANDALUCÍA       4228512      600847       Azul
# 1      1998            ASTURIAS       4852620      721222       Azul
# 2      1998            BALEARES       4129149      317212       Azul
# 3      1998  CASTILLA-LA MANCHA        568580      107089       Azul
# 4      1998            CATALUÑA       4362720     4096080       Azul
# ...     ...                 ...           ...         ...        ...
# 20872  2021    REGION DE MURCIA        702100       36464   Amarillo
# 20873  2021    REGION DE MURCIA        308360       32529   Amarillo
# 20874  2021    REGION DE MURCIA          7023         849   Amarillo
# 20875  2021    REGION DE MURCIA         20440        3111   Amarillo
# 20876  2021    REGION DE MURCIA        589310       34834   Amarillo
#
# [36192 rows x 5 columns]

# %%
print(type(final_collected))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
def count_null_values(df):
    null_counts = df.isnull().sum()
    return null_counts

# %%
final_collected=count_null_values(final_collected)
final_collected
# Out:
# AÑO             0
# CCAA            0
# KG RECOGIDOS    0
# HABITANTES      0
# CONTENEDOR      0
# dtype: int64

# %%
print(type(final_collected))
# Out:
# <class 'pandas.core.series.Series'>

# %%
final_collected.to_excel('datasets/final_collected_spain.xlsx', index=True)

# %%
SP_bins=convert_INT(SP_bins,['Amarrillos','Azules'])
SP_bins
# Out:
#      AÑO  Amarrillos  Azules
# 0   2005      268686  115427
# 1   2006      285152  128000
# 2   2007      296612  140774
# 3   2008      311485  152001
# 4   2009      324401  162848
# 5   2010      333779  172661
# 6   2011      340232  180377
# 7   2012      350427  185697
# 8   2013      352563  190564
# 9   2014      357486  195629
# 10  2015      366339  200618
# 11  2016      373272  204959
# 12  2017      378272  212852
# 13  2018      383974  217170
# 14  2019      390611  224945
# 15  2020      388174  229594
# 16  2021      383508  240297

# %%
SP_bins.to_excel('datasets/SP_bins.xlsx', index=True)

# %% [markdown]
# # Spain - Recycled

# %% [markdown]
# # Madrid - Socioeconomic

# %%
df_socio = pd.read_csv('datasets/panel_indicadores_distritos_barrios.csv', delimiter=';',encoding = 'latin-1')

# %%
df_socio
# Out:
#        Orden Periodo panel            ciudad  cod_distrito distrito
# 0          1          2019  Ciudad de Madrid           NaN      NaN  \
# 1          2          2019  Ciudad de Madrid           NaN      NaN
# 2          3          2019  Ciudad de Madrid           NaN      NaN
# 3          4          2019  Ciudad de Madrid           NaN      NaN
# 4          5          2019  Ciudad de Madrid           NaN      NaN
# ...      ...           ...               ...           ...      ...
# 55508  55813       2020-21  Ciudad de Madrid           NaN      NaN
# 55509  55814       2020-21  Ciudad de Madrid           NaN      NaN
# 55510  55815       2020-21  Ciudad de Madrid           NaN      NaN
# 55511  55816       2020-21  Ciudad de Madrid           NaN      NaN
# 55512  55817       2020-21  Ciudad de Madrid           NaN      NaN
#
#        cod_barrio barrio   año fecha_indicador
# 0             NaN    NaN  2019      01/01/2019  \
# 1             NaN    NaN  2019      01/01/2019
# 2             NaN    NaN  2019      01/01/2019
# 3             NaN    NaN  2019      01/01/2019
# 4             NaN    NaN  2019      01/01/2019
# ...           ...    ...   ...             ...
# 55508         NaN    NaN  2020            2020
# 55509         NaN    NaN  2020            2020
# 55510         NaN    NaN  2020            2020
# 55511         NaN    NaN  2020            2020
# 55512         NaN    NaN  2020            2020
#
#                                         fuente_indicador
# 0                     Estadística Ayuntamiento de Madrid  \
# 1                     Estadística Ayuntamiento de Madrid
# 2                     Estadística Ayuntamiento de Madrid
# 3                     Estadística Ayuntamiento de Madrid
# 4                     Estadística Ayuntamiento de Madrid
# ...                                                  ...
# 55508  Estudio Impacto COVID-19. DG de Innovación y E...
# 55509  Estudio Impacto COVID-19. DG de Innovación y E...
# 55510  Estudio Impacto COVID-19. DG de Innovación y E...
# 55511  Estudio Impacto COVID-19. DG de Innovación y E...
# 55512  Estudio Impacto COVID-19. DG de Innovación y E...
#
#                                          categoría_1              categoría_2
# 0      Características Generales del Distrito-Barrio                      NaN  \
# 1      Características Generales del Distrito-Barrio                      NaN
# 2                             Población del distrito  Estructura de población
# 3                             Población del distrito  Estructura de población
# 4                             Población del distrito  Estructura de población
# ...                                              ...                      ...
# 55508         Situación socioeconómica ante COVID-19     Tipología de hogares
# 55509         Situación socioeconómica ante COVID-19     Tipología de hogares
# 55510         Situación socioeconómica ante COVID-19     Tipología de hogares
# 55511         Situación socioeconómica ante COVID-19     Tipología de hogares
# 55512         Situación socioeconómica ante COVID-19     Tipología de hogares
#
#                                indicador_nivel1              indicador_nivel2
# 0                                    Superficie                           NaN  \
# 1               Población densidad de población                           NaN
# 2                          Número de Habitantes                           NaN
# 3                          Número de Habitantes                       Hombres
# 4                          Número de Habitantes                       Mujeres
# ...                                         ...                           ...
# 55508  Hogares formados por pareja sin hijos/as        Aumento ingresos hogar
# 55509  Hogares formados por pareja sin hijos/as    Disminución ingresos hogar
# 55510  Hogares formados por pareja con hijos/as  No les ha afectado la crisis
# 55511  Hogares formados por pareja con hijos/as        Aumento ingresos hogar
# 55512  Hogares formados por pareja con hijos/as    Disminución ingresos hogar
#
#       indicador_nivel3 unidad_indicador
# 0                  NaN               Ha  \
# 1                  NaN   Habitantes/Ha.
# 2                  NaN       Habitantes
# 3                  NaN       Habitantes
# 4                  NaN       Habitantes
# ...                ...              ...
# 55508              NaN       Porcentaje
# 55509              NaN       Porcentaje
# 55510              NaN       Porcentaje
# 55511              NaN       Porcentaje
# 55512              NaN       Porcentaje
#
#                                       indicador_completo valor_indicador
# 0                                      Superficie (Ha.)           60.446
# 1                         Población densidad (hab./Ha.)               54
# 2                                      Número Habitantes       3.266.126
# 3                                     Población Hombres        1.521.178
# 4                                      Población Mujeres       1.744.948
# ...                                                  ...             ...
# 55508  Hogares formados por pareja sin hijos/as. Les ...             0,9
# 55509  Hogares formados por pareja sin hijos/as. Les ...            30,6
# 55510  Hogares formados por pareja con hijos/as. No l...            53,5
# 55511  Hogares formados por pareja con hijos/as. Les ...             2,7
# 55512  Hogares formados por pareja con hijos/as. Les ...            42,5
#
# [55513 rows x 18 columns]

# %%
df_socio.columns
# Out:
# Index(['Orden', 'Periodo panel', 'ciudad', 'cod_distrito', 'distrito',
#        'cod_barrio', 'barrio', 'año', 'fecha_indicador', 'fuente_indicador',
#        'categoría_1', 'categoría_2', 'indicador_nivel1', 'indicador_nivel2',
#        'indicador_nivel3', 'unidad_indicador', 'indicador_completo',
#        'valor_indicador'],
#       dtype='object')

# %%
df_socio['distrito'].unique()
# Out:
# array([nan, 'Centro', 'Arganzuela', 'Retiro', 'Salamanca', 'Chamartín',
#        'Tetuán', 'Chamberí', 'Fuencarral-El Pardo', 'Moncloa-Aravaca',
#        'Latina', 'Carabanchel', 'Usera', 'Puente de Vallecas',
#        'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Villaverde',
#        'Villa de Vallecas', 'Vicálvaro', 'San Blas-Canillejas', 'Barajas'],
#       dtype=object)

# %%
df_socio['fuente_indicador'].unique()
# Out:
# array(['Estadística Ayuntamiento de Madrid',
#        'Encuesta de población activa',
#        'Encuesta de calidad de vida y satisfacción con los Servicios Públicos de Madrid 2019',
#        'Estudio de Necesidades Sociales en  Hogares (2016)',
#        'Consejo General del Poder Judicial',
#        'Portal web del Ayuntamiento de Madrid',
#        'Portal de datos abiertos del Ayuntamiento de Madrid',
#        'Informe "Esperanza de vida en los barrios" Madrid Salud (pendiente de publicación)',
#        'Madrid salud https://madridsalud.es/estudios-de-salud/',
#        'Estudio Impacto COVID-19. DG de Innovación y Estrategia Social',
#        'Ayuntamiento de Madrid: Servicio de planificación, coordinación e inspección catastral',
#        'Portal web de la Comunidad de Madrid',
#        'Informe Índice de envejecimiento activo de la ciudad de Madrid',
#        'Encuesta de calidad de vida y satisfacción con los Servicios Públicos de Madrid 2022',
#        'Ayuntamiento de Madrid: Departamento de gestión y prestaciones en la atención social primaria',
#        'Ayuntamiento de Madrid: Departamento de prevención del sinhogarismo y atención a personas sin hogar'],
#       dtype=object)

# %%
df_socio['indicador_completo'].unique()
# Out:
# array(['Superficie (Ha.) ', 'Población densidad (hab./Ha.) ',
#        'Número Habitantes', 'Población Hombres ', 'Población Mujeres',
#        'Edad media de la población', 'Población de 0 a 14 años   ',
#        'Población de 15 a 29         ', 'Población de 30 a 44       ',
#        'Población de 45 a 64       ', 'Población de 65 a 79       ',
#        'Población de 80 años y más           ',
#        'Población de 65 años y más          ',
#        'Población en etapa educativa (Población de 3 a 16 años -16 no incluidos)                            ',
#        'Proporción de juventud (Población de 0-15 años/Población total) porcentaje',
#        'Proporción de envejecimiento (Población mayor de 65 años/Población total)',
#        'Proporción de sobre-envejecimiento (Población mayor de 80 años/ Población mayor de 65 años)',
#        'Índice de dependencia (Población de 0-15 + población 65 años y más / Pob. 16-64) ',
#        'Personas con nacionalidad española             ',
#        'Personas con nacionalidad española Hombres                      ',
#        'Personas con nacionalidad española Mujeres                      ',
#        'Personas con nacionalidad extranjera            ',
#        'Personas con nacionalidad extranjera Hombres                       ',
#        'Personas con nacionalidad extranjera Mujeres                        ',
#        'Proporción de personas migrantes (Población extranjera menos UE y resto países de OCDE / Población total)',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nITALIA (Población total Distrito)',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nBANGLADESH (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nCHINA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nVENEZUELA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nRUMANÍA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nBOLIVIA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nECUADOR (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nFILIPINAS (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nFRANCIA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nMARRUECOS (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nPARAGUAY (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nPERÚ (Población total Distrito) ',
#        'Total hogares', 'Tamaño medio del hogar      ',
#        'Hogares con una mujer sola mayor de 65 años                      ',
#        'Hogares con un hombre solo mayor de 65 años                     ',
#        'Hogares monoparentales: una mujer adulta con uno o más menores',
#        'Hogares monoparentales: un hombre adulto con uno o más menores',
#        'Tasa de crecimiento demográfico (porcentaje)',
#        'Esperanza de vida al nacer Mujeres (mortalidad del periodo 2013-2016)',
#        'Esperanza de vida al nacer Hombres  (mortalidad del periodo 2013-2016)',
#        'Esperanza de vida al nacer Mujeres',
#        'Esperanza de vida al nacer Hombres ',
#        'Esperanza de vida mayor de 65 años Mujeres',
#        'Esperanza de vida mayor de 65 años Hombres',
#        'Índice de desigualdad de género (2018)',
#        'Índice de desigualdad de género (2008)',
#        'Renta neta media anual de los hogares (Urban Audit)             ',
#        'Renta disponible Bruta Per cápita 2016(a)',
#        'Crecimiento/decrecimiento Renta Bruta Per cápita 2016(a)-2008',
#        'Pensión media mensual Hombres ',
#        'Pensión media mensual  Mujeres\n',
#        'Tasa de actividad global ciudad de Madrid',
#        'Tasa de actividad global en Hombres ',
#        'Tasa de actividad global en Mujeres',
#        'Número de personas paradas en ciudad de Madrid',
#        'Número de personas paradas en ciudad de Madrid Hombres',
#        'Número de personas paradas en ciudad de Madrid Mujeres',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2020)       ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2020)   Hombres    ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2020)       Mujeres',
#        'Tasa absoluta de paro registrado            (Febrero  2020)',
#        'Tasa absoluta de paro registrado Mujeres',
#        'Tasa de desempleo en mujeres de 16 a 24 años',
#        'Tasa de desempleo en mujeres de 25 a 44 años',
#        'Tasa de desempleo en mujeres de 45 a 64 años',
#        'Tasa absoluta de paro registrado Hombres ',
#        'Tasa de desempleo en hombres de 16 a 24 años',
#        'Tasa de desempleo en hombres de 25 a 44 años',
#        'Tasa de desempleo en hombres de 45 a 64 años',
#        'Personas paradas de larga duración                (febrero 2020)              ',
#        'Personas paradas de larga duración                (febrero 2020)            Hombres                         ',
#        'Personas paradas de larga duración                (febrero 2020)            Mujeres                            ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2020)           ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2020)     Hombres                         ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2020)     Mujeres                         ',
#        'Personas paradas que NO perciben prestaciones (febrero 2020)',
#        'Personas paradas que NO perciben prestaciones (febrero 2020) Hombres          ',
#        'Personas paradas que NO perciben prestaciones (febrero 2020) Mujeres          ',
#        'Población en etapas educativas',
#        'Población en etapa educativa de 0 a 2 años',
#        'Población en etapa educativa de 3 a 5 años',
#        'Población en etapa educativa de 6 a 11 años',
#        'Población en etapa educativa de 12 a 15 años',
#        'Etapas educativas. Total niños',
#        'Población infantil masculina en etapa educativa de 0 a 2 años',
#        'Población infantil masculina en etapa educativa de 3 a 5 años',
#        'Población infantil masculina en etapa educativa de 6 a 11 años',
#        'Población infantil masculina en etapa educativa de 12 a 15 años',
#        'Etapas educativas. Total niñas',
#        'Población infantil femenina en etapa educativa de 0 a 2 años',
#        'Población infantil femenina en etapa educativa de 3 a 5 años',
#        'Población infantil femenina en etapa educativa de 6 a 11 años',
#        'Población infantil femenina en etapa educativa de 12 a 15 años',
#        'Escolarización del alumnado por tipo de centro ',
#        'Alumnado en Centros privados concertados',
#        'Alumnado en Centros privados sin concierto',
#        'Alumnado en Centros públicos', 'Total alumnado extranjero ',
#        'Alumnado extranjero en Centros privados concertados                   ',
#        'Alumnado extranjero en Centros privados sin concierto                  ',
#        'Alumnado extranjero en Centros públicos                        ',
#        'Alumnado con necesidades de apoyo educativo total',
#        'Alumnado con necesidades de apoyo educativo en Centros privados concertados                   ',
#        'Alumnado con necesidades de apoyo educativo en Centros privados sin concierto                  ',
#        'Alumnado con necesidades de apoyo educativo en Centros públicos                        ',
#        'No sabe leer ni escribir o sin estudios                         ',
#        'Personas con enseñanza primaria incompleta  ',
#        'Personas con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado  ',
#        'Personas con Formación profesional 2º grado, Bachiller Superior o BUP  ',
#        'Titulaciones medias, diplomaturas, arquitectura técnica o ingeniería técnica',
#        'Población mayor/igual  de 25 años  con estudios superiores, licenciatura, arquitectura, ingeniería sup., estudios sup. no universitarios, doctorado,  postgraduado  ',
#        'Nivel de estudios desconocido y no consta                                   ',
#        'Casos trabajados por el programa de absentismo municipal',
#        'Casos trabajados por el programa de absentismo municipal Hombres               ',
#        'Casos trabajados por el programa de absentismo municipal Mujeres               ',
#        'Número de personas con grado de discapacidad reconocido                               ',
#        'Número de personas con grado de discapacidad reconocido Hombres                                    ',
#        'Número de personas con grado de discapacidad reconocido Mujeres                                    ',
#        'Mujeres por cada 100 hombres (Feminización de la discapacidad reconocida)',
#        'Satisfacción de vivir en su barrio ',
#        'Calidad de vida actual en su barrio ',
#        'Satisfacción de la convivencia vecinal ',
#        'Grado de satisfacción con la organización de fiestas y eventos populares',
#        'Percepción de desigualdad en las dotaciones de los barrios   (sumando las categorías "muy alta" + "alta")',
#        'Tres principales problemas en espacios públicos: 1ºLimpieza',
#        'Tres principales problemas en espacios públicos: 2ºContaminación del aire',
#        'Tres principales problemas en espacios públicos: 3ºTráfico / atascos',
#        'Percepción de seguridad en Madrid',
#        'Percepción de seguridad en el barrio por el día',
#        'Percepción de seguridad en el barrio por la noche',
#        'Tres principales problemas en espacios públicos: 1ºPersonas orinando en la calle',
#        'Tres principales problemas en espacios públicos: 2ºExcrementos animales domésticos',
#        'Tres principales problemas en espacios públicos: 3ºConsumo o menudeo de drogas',
#        'Tres principales problemas en espacios públicos: 1ºExcrementos animales domésticos',
#        'Tres principales problemas en espacios públicos: 2ºConductas que ponen en riesgo la seguridad vial',
#        'Tres principales problemas en espacios públicos: 3ºPersonas orinando en la calle',
#        'Tres principales problemas en espacios públicos: 3ºExceso de velocidad',
#        'Tres principales problemas en espacios públicos: 2ºRobos, atracos y hurtos',
#        'Tres principales problemas en espacios públicos: 3ºConductas que ponen en riesgo la seguridad vial',
#        'Tres principales problemas en espacios públicos: 2ºPersonas orinando en la calle',
#        'Tres principales problemas en espacios públicos: 3ºMolsetias por ruido',
#        'Tres principales problemas en espacios públicos: 2ºBotellón',
#        'Tres principales problemas en espacios públicos: 3ºGrafitis',
#        'Tres principales problemas en espacios públicos: 2ºGrafitis',
#        'Tres principales problemas en espacios públicos: 3ºRobos, atracos y hurtos',
#        'Tres principales problemas en espacios públicos: 2ºConsumo o menudeo de drogas',
#        'Tres principales problemas en espacios públicos: 3ºEstacionamientos indebidos',
#        'Tres principales problemas en espacios públicos: 2ºEstacionamientos indebidos',
#        'Tres principales problemas en espacios públicos: 3ºUso indebido de parques y espacios públicos',
#        'Tres principales problemas en espacios públicos: 2ºExceso de velocidad',
#        'Preferencia de contacto con el Ayuntamiento: EN PERSONA',
#        'Percepción sobre la administración del Ayto. en los últimos 5 años: HA MEJORADO',
#        'Percepción sobre la administración del Ayto. en los últimos 5 años: HA EMPEORADO',
#        'Tasa de riesgo de pobreza o exclusión social',
#        'Tasa de riesgo de pobreza o exclusión social Hombres',
#        'Tasa de riesgo de pobreza o exclusión social Mujeres',
#        'Tasa de riesgo de pobreza o exclusión social N. ESPAÑOLA (mayor de16 años)',
#        'Tasa de riesgo de pobreza o exclusión social N. EXTRANJERA UNIÓN EUROPEA        (mayor de16 años)',
#        'Tasa de riesgo de pobreza o exclusión social N. EXTRANJERA RESTO DEL MUNDO (mayor de16 años)',
#        'Hogar formado por madre con hijos a cargo',
#        'Tasa de riesgo de pobreza para población que ha nacido en España',
#        'Tasa de riesgo de pobreza para población que ha nacido en un país fuera de la Unión Europea',
#        'Dificultad para hacer frente a los gastos derivados del suministro energético',
#        'Personas atendidas en la Unidad de Primera Atención en Centros de Servicios Sociales          ',
#        'Solicitudes tramitadas de Renta Mínima de Inserción',
#        'Perceptores de prestación de la Renta Mínima de Inserción',
#        'Personas beneficiarias de prestaciones sociales de carácter económico',
#        'Total prestaciones sociales de carácter económico ',
#        'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar)  ',
#        'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar) Hombres                                 ',
#        'Personas con Servicio de Ayuda a Domicilio (modalidad auxiliar de hogar) Mujeres                              ',
#        'Personas socias de los Centros Municipales de Mayores',
#        'Personas socias de los Centros Municipales de Mayores Hombres                      ',
#        'Personas socias de los Centros Municipales de Mayores Mujeres             ',
#        'Familias atendidas por el Equipo de Trabajo con Menores y Familia (ETMF) ',
#        'Demandas de intervención en los Centros de Atención a la Infancia (CAI)',
#        'Menores atendidos por el Servicio de Ayuda a domicilio a Menores y Familias (SAD)',
#        'Número Total de viviendas (Censo Edificios y Viviendas 2011)',
#        'Viviendas anteriores a 1980                                                                 ',
#        'Viviendas en estado ruinoso', 'Viviendas en estado malo ',
#        'Viviendas en estado deficiente  ', 'Viviendas en estado bueno ',
#        'Estado de la vivienda no costa ',
#        'Valor catastral medio de los bienes inmuebles: personas físicas en miles de \x80 ',
#        'Valor catastral medio de los bienes inmuebles: personas jurídicas en miles de \x80',
#        'Superficie media de la vivienda (m2) en transacción                    ',
#        'Duración media del crédito (meses) en transacción de vivienda ',
#        'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) ',
#        'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011) Principal                           ',
#        'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Secundaria                           ',
#        'Número Total de viviendas familiares (Censo Edificios y Viviendas 2011)  Población desocupada    ',
#        'Lanzamientos judiciales practicados (2013)',
#        'Lanzamientos judiciales como consecuencia de ejecuciones hipotecarias (2013)',
#        'Lanzamientos judiciales consecuencia de la Ley de Arrendamientos Urbanos (2013)',
#        'Lanzamientos judiciales practicados ',
#        'Lanzamientos judiciales como consecuencia de ejecuciones hipotecarias ',
#        'Lanzamientos judiciales consecuencia de la Ley de Arrendamientos Urbanos ',
#        'Partículas suspensión PM2.5 (µgr/m3) -Valor límite: 25 µgr/m3-',
#        'Partículas suspensión PM10 (µgr/m3) -Valor límite: 40 µgr/m3-',
#        'Dióxido de azufre - SO2 (µgr/m3) -Valor límite: 125 µgr/m3-',
#        'Monóxido de carbono - CO  (mg/m3) -Valor límite: 10 µgr/m3-',
#        'Ozono - O3 (µgr/m3) -Valor límite: 120 µgr/m3-',
#        'Dióxido de nitrógeno - NO2 (µgr/m3) -Valor límite: 40 µgr/m3-',
#        'Temperatura media anual (ºC)',
#        'Protocolo de contaminación: número de episodios ',
#        'Protocolo de contaminación: número de días "Escenario 1" ',
#        'Recogida domiciliaria residuos sólidos: envases y resto kg/habitante/año',
#        'Recogida domiciliaria residuos sólidos: envases y resto kg/habitante/día',
#        'Intervenciones de la Policía Municipal en materia de seguridad: delitos relacionados con las personas',
#        'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia de armas',
#        'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con el patrimonio',
#        'Intervenciones de la Policía Municipal en materia de seguridad: relacionadas con la tenencia y consumo de drogas',
#        'Expedientes instruidos por Agentes Tutores',
#        'Atestados/partes de accidentes de tráfico confeccionados',
#        'Personas detenidas e investigadas por la Policía Municipal en materia de seguridad: Total  personas detenidas e investigadas ',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Lesiones',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Violencia doméstica y de género',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Malos tratos a menores',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Abusos y agresiones sexuales ',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Hurtos',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Robo con violencia e intimidación en personas',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Contra la salud pública  ',
#        'Personas detenidas e investigadas por la Policía Municipal  en materia de seguridad: Contra la seguridad vial  ',
#        'Elecciones Municipales 2019: Censo electoral',
#        'Abstenciones en elecciones municipales de 2019',
#        'Votos en blanco en elecciones municipales de 2019',
#        'Votos a candidaturas',
#        'Votos a Más Madrid en elecciones municipales de 2019',
#        'Votos a PP en elecciones municipales de 2019',
#        'Votos a Ciudadanos en elecciones municipales de 2019',
#        'Votos a PSOE en elecciones municipales de 2019 ',
#        'Votos a VOX en elecciones municipales de 2019',
#        'Centros de Servicios Sociales', 'Centros Municipales de Mayores ',
#        'Centros de Día de Alzheimer y Físicos',
#        'Apartamentos Municipales para Mayores',
#        'Residencias para personas Mayores ',
#        'Centros de Apoyo a las Familias (CAF)',
#        'Centros de Atención a la Infancia (CAI)',
#        'Centro de Día de Atención a Niños y Niñas (de 3 a 12 años)',
#        'Espacios de Ocio para Adolescentes (El Enredadero)',
#        'Centros de Adolescentes y Jóvenes (ASPA) ',
#        'Centros para personas sin hogar ', 'Espacios de Igualdad ',
#        'Centros Municipales de Salud Comunitaria (CMSC)',
#        'Centros de Atención a las Adicciones (CAD y CCAD)',
#        'Bibliotecas Municipales', 'Bibliotecas Comunidad Madrid',
#        'Centros y Espacios Culturales', 'Centros deportivos Municipales',
#        'Superficie deportiva m2 ', 'Instalaciones deportivas básicas',
#        'Instalaciones deportivas de acceso controlado ',
#        'Campos de fútbol 11', 'Pista de atletismo ', 'Piscinas cubiertas',
#        'Piscinas de verano',
#        'Superficie de zonas verdes y Parques de distrito (ha)',
#        'Relación de Superficie de zonas verdes y Parques de distrito (ha) entre número de Habitantes *10.000',
#        'Superficie de Parques Históricos, Singulares y Forestales por distrito  ',
#        'Superficie de Parques Históricos, Singulares y Forestales por distrito  entre número de Habitantes *10.000',
#        'Escuelas Infantiles Municipales', 'Escuelas Infantiles Públicas ',
#        'Escuelas Infantiles Privadas                                ',
#        'Colegios Públicos Infantil y Primaria ',
#        'Institutos Públicos de Educación Secundaria',
#        'Colegios Privados Inf. o Pri. o Inf. y Pri.',
#        'Colegios Privados Inf., Pri. y Sec. o Pri. y Sec.',
#        'Mercados Municipales',
#        'Asociaciones culturales y casas regionales',
#        'Asociaciones de mujeres', 'Asociaciones vecinales',
#        'Asociaciones (Sección 1ª)', 'Fundaciones (Sección 2ª)',
#        'Índice de vulnerabilidad territorial ',
#        'Posición en el ranking de distritos y/o barrios de vulnerabilidad territorial',
#        'Superficie media de la vivienda (m2) en transacción',
#        'Población de 15 a 29 años', 'Población de 30 a 44  años',
#        'Población de 45 a 64 años', 'Población de 65 a 79 años      ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: ITALIA (Población total Distrito)            ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: \nBANGLADESH (Población total Distrito)',
#        'Primera y segunda nacionalidad extranjera en el Distrito: FILIPINAS (Población total Distrito) ',
#        'Tasa bruta de natalidad (\x89)',
#        'Índice de desigualdad de género (2019)',
#        'Índice de desigualdad de género (2009)',
#        'Renta neta media anual de los hogares (Urban Audit)                ',
#        'Renta disponible Bruta Per cápita 2017(a)',
#        'Crecimiento/decrecimiento Renta Bruta Per cápita 2017(a)-2008',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2021) ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2021)   Hombres    ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2021) Mujeres',
#        'Tasa absoluta de paro registrado (Febrero  2021)',
#        'Personas paradas de larga duración (febrero 2021)              ',
#        'Personas paradas de larga duración  (febrero 2021) Hombres                         ',
#        'Personas paradas de larga duración  (febrero 2021)  Mujeres                            ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2021)      ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2021)     Hombres                         ',
#        'Personas paradas que SÍ perciben prestaciones    (febrero 2021)     Mujeres                         ',
#        'Personas paradas que NO perciben prestaciones (febrero 2021)',
#        'Personas paradas que NO perciben prestaciones (febrero 2021) Hombres          ',
#        'Personas paradas que NO perciben prestaciones (febrero 2021) Mujeres          ',
#        'Escolarización del alumnado por tipo de centro',
#        'Población mayor/igual  de 25 años  que no sabe leer ni escribir o sin estudios                ',
#        'Población mayor/igual  de 25 años con enseñanza primaria incompleta  ',
#        'Población mayor/igual  de 25 años con Bachiller Elemental, Graduado Escolar, ESO, Formación profesional 1º grado  ',
#        'Población mayor/igual  de 25 años con Formación profesional 2º grado, Bachiller Superior o BUP  ',
#        'Población mayor/igual  de 25 años con titulación media, diplomatura, arquitectura o ingeniería técnica    ',
#        'Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta                                   ',
#        'Casos trabajados por el programa de absentismo municipal ',
#        'Sedentarismo', 'Sedentarismo Hombres ', 'Sedentarismo Mujeres ',
#        'Consumo de tabaco diario', 'Consumo de tabaco diario Hombres',
#        'Consumo de tabaco diario Mujeres ', 'Consumo de medicamentos ',
#        'Consumo de medicamentos Hombres  ',
#        'Consumo de medicamentos Mujeres ',
#        'Autopercepción de buen estado de salud  (porcentaje respuesta muy buena + buena)',
#        'Autopercepción de buen estado de salud           Hombres ',
#        'Autopercepción de buen estado de salud                   Mujeres ',
#        'Calidad de vida relacionada con la salud (CVRS) ',
#        'Calidad de vida relacionada con la salud (CVRS) Hombres',
#        'Calidad de vida relacionada con la salud (CVRS) Mujeres',
#        'Presencia de enfermedad crónica ',
#        'Presencia de enfermedad crónica        Hombres ',
#        'Presencia de enfermedad crónica            Mujeres',
#        'Hipertensión arterial', 'Hipertensión arterial         Hombres',
#        'Hipertensión arterial         Mujeres', 'Diabetes Mellitus',
#        'Diabetes Mellitus Hombres', 'Diabetes Mellitus Mujeres',
#        'Personas con obesidad ', 'Personas con obesidad Hombres ',
#        'Personas con obesidad Mujeres', 'Personas con sobrepeso',
#        'Personas con sobrepeso Hombres', 'Personas con sobrepeso Mujeres',
#        'Alguna dependencia funcional Hombres ',
#        'Alguna dependencia funcional Mujeres',
#        'Prevalencia de obesidad en la población infantil (2017. Estudio Madrid Salud. UCM)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)          (2018. EMS)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres           (2018. EMS)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)  Mujeres           (2018. EMS)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Abril 2020',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres Abril 2020',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Mujeres Abril 2020',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Octubre 2020',
#        'Probabilidad de padecer enfermedad mental (GHQ-12) Hombres Octubre 2020',
#        'Probabilidad de padecer enfermedad mental(GHQ-12)  Mujeres Octubre 2020',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años (ENS, 2017)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años (ENS, 2017)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años (ENS, 2017)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (ENS, 2017)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años (Abril, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años (Abril, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años (Abril, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (Abril, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 18-29 años  (Octubre, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 30-44 años  (Octubre, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 45-64 años  (Octubre, 2020)',
#        'Probabilidad de padecer enfermedad mental (GHQ-12)   entre 65 y más años (Octubre, 2020)',
#        'Grado de satisfacción con los espacios verdes',
#        'Grado de satisfacción con los parques infantiles ',
#        'Grado de satisfacción con los centros culturales',
#        'Grado de satisfacción con las instalaciones deportivas',
#        'Grado de satisfacción de los servicios sociales municipales',
#        'Grado de preferencia como medio de información de la actividad del Ayuntamiento: REDES SOCIALES',
#        'Madrid ciudad amigable con las personas lesbianas, gays, transexuales y bisexuales',
#        'Personas perceptoras de prestación de la Renta Mínima de Inserción',
#        'Número de inmuebles de uso residencial ',
#        'Superficie media construida (m2) inmuebles de uso residencial 2019',
#        'Año medio de contrucción de inmuebles de uso residencial ',
#        'Lanzamientos judiciales practicados',
#        'Inspecciones y actuaciones en locales de espectáculos públicos y actividades recreativas  ',
#        'Personas paradas de larga duración                (febrero 2021)            Hombres                         ',
#        'Personas paradas de larga duración                (febrero 2021)            Mujeres                            ',
#        'Casos trabajados por el programa de absentismo municipal Hombres                        ',
#        'Casos trabajados por el programa de absentismo municipal Mujeres                                  ',
#        'Población mayor/igual  de 25 años con Nivel de estudios desconocido y/o no consta porcentaje',
#        'Duración media del crédito (meses) en transacción de vivienda (2019) ',
#        'Índice de envejecimiento activo',
#        'Índice de envejecimiento activo en  Hombres ',
#        'Índice de envejecimiento activo en  Mujeres',
#        'Personas con nacionalidad española Mujeres                         ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: CHINA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: VENEZUELA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: FRANCIA (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: MARRUECOS (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: PARAGUAY (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: PERÚ (Población total Distrito) ',
#        'Primera y segunda nacionalidad extranjera en el Distrito: COLOMBIA (Población total Distrito) ',
#        'Renta disponible Bruta Per cápita 2019',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2022) ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2022) Hombres',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2022) Mujeres',
#        'Tasa absoluta de paro registrado (Febrero  2022)',
#        'Personas paradas de larga duración (febrero 2022)              ',
#        'Personas paradas de larga duración (febrero 2022) Hombres                         ',
#        'Personas paradas de larga duración (febrero 2022) Mujeres                            ',
#        'Personas paradas que SÍ perciben prestaciones (febrero 2022)      ',
#        'Personas paradas que SÍ perciben prestaciones (febrero 2022) Hombres                         ',
#        'Personas paradas que SÍ perciben prestaciones (febrero 2022) Mujeres                         ',
#        'Personas paradas que NO perciben prestaciones (febrero 2022)',
#        'Personas paradas que NO perciben prestaciones (febrero 2022) Hombres          ',
#        'Personas paradas que NO perciben prestaciones (febrero 2022) Mujeres          ',
#        'Número de personas con grado de discapacidad reconocido Mujeres                                ',
#        'Medida en la que la ciudadania se siente informada de lo que hace el Ayuntamiento',
#        'Madrid ciudad amigable con las personas lesbianas, gays, transexuales y bisexuales ',
#        'Superficie media de la vivienda (m2) en transacción                                                ',
#        'Centro de Día de Atención a Niños y Niñas (de 3 a 12 años) ',
#        'Paro registrado (número de personas registradas en SEPE en Febrero 2022) Hombres    ',
#        'Hogar Unipersonal, de personas de menos de 65 años. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#        'Hogar Unipersonal, de personas de menos de 65 años. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#        'Hogar Unipersonal, de personas de menos de 65 años. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#        'Hogar Unipersonal, de personas de  65 años o más. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#        'Hogar Unipersonal, de personas de  65 años o más. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#        'Hogar Unipersonal, de personas de  65 años o más. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#        'Hogares monoparentales. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#        'Hogares monoparentales. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#        'Hogares monoparentales. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja sin hijos/as. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja sin hijos/as. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja sin hijos/as. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja con hijos/as. No les ha afectado la crisis del coronavirus en los ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja con hijos/as. Les ha afectado la crisis del coronavirus en el aumento de sus  ingresos del hogar (octubre 2020)',
#        'Hogares formados por pareja con hijos/as. Les ha afectado la crisis del coronavirus en la disminución de sus ingresos del hogar (octubre 2020)'],
#       dtype=object)

# %% [markdown]
# # Madrid - data - Collected waste

# %%
df_MA_22 = pd.read_excel('datasets/Modelo_Residuos_2022.xlsx')
df_MA_22
# Out:
#        Año        Mes  Lote      Fracción  Distrito                 NOMBRE
# 0     2022      enero     1  PAPEL-CARTON         1                 Centro  \
# 1     2022      enero     1  PAPEL-CARTON         6                 Tetuán
# 2     2022      enero     1  PAPEL-CARTON         7               Chamberí
# 3     2022      enero     1  PAPEL-CARTON         8  Fuencarral - El Pardo
# 4     2022      enero     1  PAPEL-CARTON         9      Moncloa - Aravaca
# ...    ...        ...   ...           ...       ...                    ...
# 2189  2022  diciembre     3          ROPA        11            Carabanchel
# 2190  2022  diciembre     3          ROPA        12                  Usera
# 2191  2022  diciembre     3          ROPA        13     Puente de Vallecas
# 2192  2022  diciembre     3          ROPA        17             Villaverde
# 2193  2022  diciembre     3          ROPA        18      Villa de Vallecas
#
#         Total
# 0     395.860
# 1     381.980
# 2     312.760
# 3     692.250
# 4     300.380
# ...       ...
# 2189    1.335
# 2190    3.895
# 2191    2.965
# 2192    2.015
# 2193    1.410
#
# [2194 rows x 7 columns]

# %%
df_MA_22['NOMBRE'].unique()
# Out:
# array(['Centro', 'Tetuán', 'Chamberí', 'Fuencarral - El Pardo',
#        'Moncloa - Aravaca', 'Latina', 'Retiro', 'Salamanca', 'Chamartín',
#        'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Vicálvaro',
#        'San Blas - Canillejas', 'Barajas', 'Arganzuela', 'Carabanchel',
#        'Usera', 'Puente de Vallecas', 'Villaverde', 'Villa de Vallecas',
#        'Sin Distrito'], dtype=object)

# %%
df_MA_22['NOMBRE'].value_counts()['Sin Distrito']
# Out:
# 19

# %%
df_MA_22['NOMBRE'].value_counts()
# Out:
# NOMBRE
# Moncloa - Aravaca        127
# Puente de Vallecas       118
# Fuencarral - El Pardo    112
# Latina                   112
# Centro                   110
# Retiro                   110
# Salamanca                110
# Ciudad Lineal            110
# Usera                    109
# Tetuán                   100
# Moratalaz                100
# Hortaleza                 99
# Vicálvaro                 98
# San Blas - Canillejas     98
# Barajas                   98
# Arganzuela                98
# Chamartín                 98
# Villaverde                98
# Carabanchel               97
# Villa de Vallecas         87
# Chamberí                  86
# Sin Distrito              19
# Name: count, dtype: int64

# %%
df_MA_22['Fracción'].unique()
# Out:
# array(['PAPEL-CARTON', 'CARTON COMERCIAL', 'CAMA DE CABALLO', 'CLINICOS',
#        'ENVASES', 'ORGANICA', 'PUNTOS LIMPIOS', 'RCD', 'RESTO', 'VIDRIO',
#        'VIDRIO COMERCIAL', 'CONTENEDORES DE ROPA', 'ANIMALES MUERTOS',
#        'PILAS', 'ROPA'], dtype=object)

# %%
nulls=df_MA_22.isnull().any()
print(nulls)
# Out:
# Año         False
# Mes         False
# Lote        False
# Fracción    False
# Distrito    False
# NOMBRE      False
# Total       False
# dtype: bool

# %%
df_MA_22.rename(columns={'NOMBRE': 'Nombre Distrito', 'Total': 'Toneladas'}, inplace=True)

# %%
df_MA_22[df_MA_22['Nombre Distrito'] == 'Sin Distrito']
# Out:
#        Año         Mes  Lote          Fracción  Distrito Nombre Distrito
# 178   2022       enero     3  ANIMALES MUERTOS        99    Sin Distrito  \
# 359   2022     febrero     3  ANIMALES MUERTOS        99    Sin Distrito
# 360   2022     febrero     3             PILAS        99    Sin Distrito
# 540   2022       marzo     3  ANIMALES MUERTOS        99    Sin Distrito
# 541   2022       marzo     3             PILAS        99    Sin Distrito
# 722   2022       abril     3  ANIMALES MUERTOS        99    Sin Distrito
# 901   2022        mayo     3  ANIMALES MUERTOS        99    Sin Distrito
# 902   2022        mayo     3             PILAS        99    Sin Distrito
# 1081  2022       junio     3  ANIMALES MUERTOS        99    Sin Distrito
# 1082  2022       junio     3             PILAS        99    Sin Distrito
# 1260  2022       julio     3  ANIMALES MUERTOS        99    Sin Distrito
# 1261  2022       julio     3             PILAS        99    Sin Distrito
# 1440  2022      agosto     3  ANIMALES MUERTOS        99    Sin Distrito
# 1620  2022  septiembre     3  ANIMALES MUERTOS        99    Sin Distrito
# 1621  2022  septiembre     3             PILAS        99    Sin Distrito
# 1802  2022     octubre     3  ANIMALES MUERTOS        99    Sin Distrito
# 1988  2022   noviembre     3             RESTO        99    Sin Distrito
# 1995  2022   noviembre     3  ANIMALES MUERTOS        99    Sin Distrito
# 2187  2022   diciembre     3  ANIMALES MUERTOS        99    Sin Distrito
#
#       Toneladas
# 178       6.300
# 359       7.960
# 360       2.190
# 540      10.500
# 541       6.270
# 722       7.300
# 901       9.560
# 902       4.390
# 1081      9.180
# 1082      4.180
# 1260      9.740
# 1261      2.990
# 1440      6.600
# 1620      7.460
# 1621      4.210
# 1802      7.960
# 1988      5.042
# 1995      6.560
# 2187      9.800

# %%
df_MA_21= pd.read_excel('datasets/Modelo_Residuos_2021.xlsx')
df_MA_21
# Out:
#        Año        Mes  Lote           Residuo  Distrito
# 0     2021      enero     1             RESTO         1  \
# 1     2021      enero     1             RESTO         6
# 2     2021      enero     1             RESTO         7
# 3     2021      enero     1             RESTO         8
# 4     2021      enero     1             RESTO         9
# ...    ...        ...   ...               ...       ...
# 2133  2021  diciembre     3    PUNTOS LIMPIOS        13
# 2134  2021  diciembre     3    PUNTOS LIMPIOS        17
# 2135  2021  diciembre     3    PUNTOS LIMPIOS        18
# 2136  2021  diciembre     3  ANIMALES MUERTOS        99
# 2137  2021  diciembre     3             PILAS        99
#
#             Nombre Distrito  Toneladas
# 0                    Centro    3477.92
# 1                    Tetuán    2701.32
# 2                  Chamberí    2403.34
# 3     Fuencarral - El Pardo    4017.66
# 4         Moncloa - Aravaca    2873.78
# ...                     ...        ...
# 2133     Puente de Vallecas      23.80
# 2134             Villaverde      37.66
# 2135      Villa de Vallecas      63.66
# 2136           Sin Distrito       8.62
# 2137           Sin Distrito       6.48
#
# [2138 rows x 7 columns]

# %%
df_MA_21.rename(columns={'Residuo': 'Fracción'}, inplace=True)
df_MA_21
# Out:
#        Año        Mes  Lote          Fracción  Distrito
# 0     2021      enero     1             RESTO         1  \
# 1     2021      enero     1             RESTO         6
# 2     2021      enero     1             RESTO         7
# 3     2021      enero     1             RESTO         8
# 4     2021      enero     1             RESTO         9
# ...    ...        ...   ...               ...       ...
# 2133  2021  diciembre     3    PUNTOS LIMPIOS        13
# 2134  2021  diciembre     3    PUNTOS LIMPIOS        17
# 2135  2021  diciembre     3    PUNTOS LIMPIOS        18
# 2136  2021  diciembre     3  ANIMALES MUERTOS        99
# 2137  2021  diciembre     3             PILAS        99
#
#             Nombre Distrito  Toneladas
# 0                    Centro    3477.92
# 1                    Tetuán    2701.32
# 2                  Chamberí    2403.34
# 3     Fuencarral - El Pardo    4017.66
# 4         Moncloa - Aravaca    2873.78
# ...                     ...        ...
# 2133     Puente de Vallecas      23.80
# 2134             Villaverde      37.66
# 2135      Villa de Vallecas      63.66
# 2136           Sin Distrito       8.62
# 2137           Sin Distrito       6.48
#
# [2138 rows x 7 columns]

# %%
df_MA_21_22=pd.concat([df_MA_22,df_MA_21], ignore_index=True)

# %%
df_MA_21_22['Fracción'].unique()
# Out:
# array(['PAPEL-CARTON', 'CARTON COMERCIAL', 'CAMA DE CABALLO', 'CLINICOS',
#        'ENVASES', 'ORGANICA', 'PUNTOS LIMPIOS', 'RCD', 'RESTO', 'VIDRIO',
#        'VIDRIO COMERCIAL', 'CONTENEDORES DE ROPA', 'ANIMALES MUERTOS',
#        'PILAS', 'ROPA'], dtype=object)

# %%
df_MA_21_22.dtypes
# Out:
# Año                  int64
# Mes                 object
# Lote                 int64
# Fracción            object
# Distrito             int64
# Nombre Distrito     object
# Toneladas          float64
# dtype: object

# %%
df_MA_20 = pd.read_excel('datasets/Modelo_Residuos_2020.xlsx')

# %%
df_MA_20['FRACCIÓN'].unique()
# Out:
# array(['RESTO', 'ENVASES', 'VIDRIO', 'CLINICOS', 'ORGÁNICA',
#        'PUNTOS LIMPIOS', 'PILAS', 'ANIMALES MUERTOS', 'CARTÓN COMERCIAL',
#        'PAPEL-CARTÓN', 'RCD', 'VIDRIO COMERCIAL',
#        'CONTENEDORES ROPA USADA', 'RESIDUOS DEPOSITADOS MIGAS CALIENTES',
#        nan, 'Papel Incautado Policía', 'Cartón limpieza viaria'],
#       dtype=object)

# %%
df_MA_20
# Out:
#         LOTE           DISTRITO                              FRACCIÓN
# 0           1        01. CENTRO                                 RESTO  \
# 1           1        01. CENTRO                               ENVASES
# 2           1        01. CENTRO                                VIDRIO
# 3           1        01. CENTRO                              CLINICOS
# 4           1        01. CENTRO                              ORGÁNICA
# ..        ...               ...                                   ...
# 130         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 131       NaN               NaN                                   NaN
# 132       NaN               NaN                                   NaN
# 133  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 134  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#      ENERO '20(TN)  FEBRERO '20(TN)  MARZO '20(TN)  ABRIL '20(TN)
# 0          6023.78          5831.06        4172.66        2488.66  \
# 1           235.84           231.92         206.44         173.14
# 2           723.82           712.72         428.52         293.62
# 3           176.02           181.50         245.84         587.70
# 4             0.00             0.00           0.00           0.00
# ..             ...              ...            ...            ...
# 130           0.00             0.00           0.00           0.00
# 131            NaN              NaN            NaN            NaN
# 132            NaN              NaN            NaN            NaN
# 133           0.00             0.00           0.00           0.00
# 134          98.00            82.90          47.83          20.56
#
#      MAYO '20(TN)  JUNIO'20(TN)  JULIO'20(TN)  AGOSTO'20(TN)
# 0         2956.40       3500.46       3749.66        3037.50  \
# 1          217.78        216.44        198.64         167.38
# 2          318.08        405.82        384.68         319.08
# 3          645.86        535.54        161.96         123.00
# 4            0.00          0.00          0.00           0.00
# ..            ...           ...           ...            ...
# 130          0.00          0.00          0.00           0.00
# 131           NaN           NaN           NaN            NaN
# 132           NaN           NaN           NaN            NaN
# 133          0.00          0.00          0.00           0.00
# 134         43.79         62.83         42.19          29.02
#
#      SEPTIEMBRE'20(TN)  OCTUBRE'20(TN)  NOVIEMBRE'20(TN)  DICIEMBRE'20(TN)
# 0              3301.84         3276.00           3315.74           3630.82
# 1               220.90          226.86            213.76            224.86
# 2               431.96          448.00            469.60            637.66
# 3               151.50          164.34            150.18            152.42
# 4               424.52          539.64            578.50            659.54
# ..                 ...             ...               ...               ...
# 130               0.00            0.00              0.00              0.00
# 131                NaN             NaN               NaN               NaN
# 132                NaN             NaN               NaN               NaN
# 133               0.89            0.00              1.79              0.00
# 134              52.11           59.67             42.25              0.00
#
# [135 rows x 15 columns]

# %%
df_MA_20.columns
# Out:
# Index(['LOTE ', 'DISTRITO', 'FRACCIÓN', 'ENERO '20(TN)', 'FEBRERO '20(TN)',
#        'MARZO '20(TN)', 'ABRIL '20(TN)', 'MAYO '20(TN)', 'JUNIO'20(TN)',
#        'JULIO'20(TN)', 'AGOSTO'20(TN)', 'SEPTIEMBRE'20(TN)', 'OCTUBRE'20(TN)',
#        'NOVIEMBRE'20(TN)', 'DICIEMBRE'20(TN)'],
#       dtype='object')

# %%
def transformar_meses(df, meses):
    df = df.melt(id_vars=['LOTE ', 'DISTRITO', 'FRACCIÓN'], value_vars=meses, var_name='mes', value_name='valor')
    return df

# %%
import pandas as pd

def transformar_meses(df, meses):
    # Filtrar las columnas que contienen los nombres de los meses
    columnas_meses = [col for col in df.columns if col in meses]

    # Transformar las columnas de meses utilizando el método melt()
    df_transformado = df.melt(id_vars=['LOTE ', 'DISTRITO', 'FRACCIÓN'], value_vars=columnas_meses, var_name='mes', value_name='valor')

    return df_transformado

meses = ['ENERO \'20(TN)', 'FEBRERO \'20(TN)', 'MARZO \'20(TN)', 'ABRIL \'20(TN)', 'MAYO \'20(TN)', 'JUNIO\'20(TN)',
         'JULIO\'20(TN)', 'AGOSTO\'20(TN)', 'SEPTIEMBRE\'20(TN)', 'OCTUBRE\'20(TN)', 'NOVIEMBRE\'20(TN)', 'DICIEMBRE\'20(TN)']

df_trans_20 = transformar_meses(df_MA_20, meses)
df_trans_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1615         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1616       NaN               NaN                                   NaN
# 1617       NaN               NaN                                   NaN
# 1618  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1619  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor
# 0        ENERO '20(TN)  6023.78
# 1        ENERO '20(TN)   235.84
# 2        ENERO '20(TN)   723.82
# 3        ENERO '20(TN)   176.02
# 4        ENERO '20(TN)     0.00
# ...                ...      ...
# 1615  DICIEMBRE'20(TN)     0.00
# 1616  DICIEMBRE'20(TN)      NaN
# 1617  DICIEMBRE'20(TN)      NaN
# 1618  DICIEMBRE'20(TN)     0.00
# 1619  DICIEMBRE'20(TN)     0.00
#
# [1620 rows x 5 columns]

# %%
df_trans_20['Año'] = 2020
df_trans_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1615         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1616       NaN               NaN                                   NaN
# 1617       NaN               NaN                                   NaN
# 1618  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1619  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor   Año
# 0        ENERO '20(TN)  6023.78  2020
# 1        ENERO '20(TN)   235.84  2020
# 2        ENERO '20(TN)   723.82  2020
# 3        ENERO '20(TN)   176.02  2020
# 4        ENERO '20(TN)     0.00  2020
# ...                ...      ...   ...
# 1615  DICIEMBRE'20(TN)     0.00  2020
# 1616  DICIEMBRE'20(TN)      NaN  2020
# 1617  DICIEMBRE'20(TN)      NaN  2020
# 1618  DICIEMBRE'20(TN)     0.00  2020
# 1619  DICIEMBRE'20(TN)     0.00  2020
#
# [1620 rows x 6 columns]

# %%
df_trans_20['mes'].unique()
# Out:
# array(["ENERO '20(TN)", "FEBRERO '20(TN)", "MARZO '20(TN)",
#        "ABRIL '20(TN)", "MAYO '20(TN)", "JUNIO'20(TN)", "JULIO'20(TN)",
#        "AGOSTO'20(TN)", "SEPTIEMBRE'20(TN)", "OCTUBRE'20(TN)",
#        "NOVIEMBRE'20(TN)", "DICIEMBRE'20(TN)"], dtype=object)

# %%
df_MA_19 = pd.read_excel('datasets/Modelo_Residuos_2019.xlsx')
df_MA_19
# Out:
#         LOTE           DISTRITO                              FRACCIÓN
# 0           1        01. CENTRO                                 RESTO  \
# 1           1        01. CENTRO                               ENVASES
# 2           1        01. CENTRO                                VIDRIO
# 3           1        01. CENTRO                              CLINICOS
# 4           1        01. CENTRO                              ORGÁNICA
# ..        ...               ...                                   ...
# 125         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 126       NaN               NaN                                   NaN
# 127       NaN               NaN                                   NaN
# 128  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 129  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#      ENERO '19(TN)  FEBRERO '19(TN)  MARZO '19(TN)  ABRIL '19(TN)
# 0          6099.24          5643.16        6358.28        5923.36  \
# 1           201.66           191.92         219.30         205.92
# 2           668.56           612.76         706.20         669.12
# 3           139.10           152.88         173.58         170.48
# 4             0.00             0.00           0.00           0.00
# ..             ...              ...            ...            ...
# 125          23.53             3.21           1.45           0.00
# 126            NaN              NaN            NaN            NaN
# 127            NaN              NaN            NaN            NaN
# 128           7.42             0.21           5.91           7.28
# 129          95.80            99.54         101.94          96.54
#
#      MAYO '19(TN)  JUNIO'19(TN)  JULIO'19(TN)  AGOSTO'19(TN)
# 0         6361.46       6244.32       5935.02        4864.96  \
# 1          225.40        222.86        205.70         177.78
# 2          716.72        684.26        602.40         474.56
# 3          165.50        160.88        157.64         122.64
# 4            0.00          0.00          0.00           0.00
# ..            ...           ...           ...            ...
# 125          0.00          0.00          0.00           0.00
# 126           NaN           NaN           NaN            NaN
# 127           NaN           NaN           NaN            NaN
# 128          0.60          1.11          0.00           0.00
# 129        109.44        115.64         80.45          58.11
#
#      SEPTIEMBRE'19(TN)  OCTUBRE'19(TN)  NOVIEMBRE'19(TN)  DICIEMBRE'19(TN)
# 0              5831.70         6375.50           6133.30           6593.32
# 1               225.74          238.30            229.12            238.16
# 2               665.64          751.24            745.36            858.58
# 3               153.26          182.52            171.12            154.98
# 4                 0.00            0.00              0.00              0.00
# ..                 ...             ...               ...               ...
# 125               0.00            0.00              0.00              0.00
# 126                NaN             NaN               NaN               NaN
# 127                NaN             NaN               NaN               NaN
# 128               0.00            0.00              0.00              0.00
# 129              87.78           88.93             63.42             87.21
#
# [130 rows x 15 columns]

# %%
df_MA_19.columns
# Out:
# Index(['LOTE ', 'DISTRITO', 'FRACCIÓN', 'ENERO '19(TN)', 'FEBRERO '19(TN)',
#        'MARZO '19(TN)', 'ABRIL '19(TN)', 'MAYO '19(TN)', 'JUNIO'19(TN)',
#        'JULIO'19(TN)', 'AGOSTO'19(TN)', 'SEPTIEMBRE'19(TN)', 'OCTUBRE'19(TN)',
#        'NOVIEMBRE'19(TN)', 'DICIEMBRE'19(TN)'],
#       dtype='object')

# %%
import pandas as pd

def transformar_meses(df, meses):
    df = df.melt(id_vars=['LOTE ', 'DISTRITO', 'FRACCIÓN'], value_vars=meses, var_name='mes', value_name='valor')
    return df

# %%
meses = ['ENERO \'19(TN)', 'FEBRERO \'19(TN)', 'MARZO \'19(TN)',
                    'ABRIL \'19(TN)', 'MAYO \'19(TN)', 'JUNIO\'19(TN)', 'JULIO\'19(TN)', 'AGOSTO\'19(TN)',
                    'SEPTIEMBRE\'19(TN)', 'OCTUBRE\'19(TN)', 'NOVIEMBRE\'19(TN)', 'DICIEMBRE\'19(TN)']

df_trans_19 = transformar_meses(df_MA_19,meses)
df_trans_19
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1555         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1556       NaN               NaN                                   NaN
# 1557       NaN               NaN                                   NaN
# 1558  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1559  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor
# 0        ENERO '19(TN)  6099.24
# 1        ENERO '19(TN)   201.66
# 2        ENERO '19(TN)   668.56
# 3        ENERO '19(TN)   139.10
# 4        ENERO '19(TN)     0.00
# ...                ...      ...
# 1555  DICIEMBRE'19(TN)     0.00
# 1556  DICIEMBRE'19(TN)      NaN
# 1557  DICIEMBRE'19(TN)      NaN
# 1558  DICIEMBRE'19(TN)     0.00
# 1559  DICIEMBRE'19(TN)    87.21
#
# [1560 rows x 5 columns]

# %%
df_trans_19['Año'] = 2019
df_trans_19
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1555         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1556       NaN               NaN                                   NaN
# 1557       NaN               NaN                                   NaN
# 1558  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1559  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor   Año
# 0        ENERO '19(TN)  6099.24  2019
# 1        ENERO '19(TN)   201.66  2019
# 2        ENERO '19(TN)   668.56  2019
# 3        ENERO '19(TN)   139.10  2019
# 4        ENERO '19(TN)     0.00  2019
# ...                ...      ...   ...
# 1555  DICIEMBRE'19(TN)     0.00  2019
# 1556  DICIEMBRE'19(TN)      NaN  2019
# 1557  DICIEMBRE'19(TN)      NaN  2019
# 1558  DICIEMBRE'19(TN)     0.00  2019
# 1559  DICIEMBRE'19(TN)    87.21  2019
#
# [1560 rows x 6 columns]

# %%
df_MA_18 = pd.read_excel('datasets/Modelo_Residuos_2018.xlsx')
df_MA_18
# Out:
#      LOTE           DISTRITO                              FRACCIÓN
# 0        1        01. CENTRO                                 RESTO  \
# 1        1        01. CENTRO                               ENVASES
# 2        1        01. CENTRO                                VIDRIO
# 3        1        01. CENTRO                              CLINICOS
# 4        1        01. CENTRO                              ORGÁNICA
# ..     ...               ...                                   ...
# 121      2  99. SIN DISTRITO               CONTENEDORES ROPA USADA
# 122      3  99. SIN DISTRITO               CONTENEDORES ROPA USADA
# 123      1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 124      2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 125      3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
#
#      ENERO '18(TN)  FEBRERO '18(TN)  MARZO '18(TN)  ABRIL '18(TN)
# 0         6248.640         5722.500       6376.180        6334.00  \
# 1          159.280          152.580        169.940         178.52
# 2          606.840          540.620        582.820         627.06
# 3          130.760          128.920        135.460         134.82
# 4            0.000            0.000          0.000           0.00
# ..             ...              ...            ...            ...
# 121          0.360            1.260          0.900           0.18
# 122          0.360            0.180          0.360           0.00
# 123         30.235           48.515         53.105          53.25
# 124          0.000            0.000          0.000           0.00
# 125          0.000            0.000          0.000           0.00
#
#      MAYO '18(TN)  JUNIO'18(TN)  JULIO'18(TN)  AGOSTO'18(TN)
# 0        6544.600      6359.240       6034.72        4908.30  \
# 1         186.440       186.740        176.24         147.08
# 2         654.420       620.380        536.80         426.08
# 3         130.500       132.220        119.66          97.98
# 4           0.000         0.000          0.00           0.00
# ..            ...           ...           ...            ...
# 121         0.720         1.080          1.08           1.08
# 122         0.900         0.540          0.18           0.18
# 123        49.795        52.095         60.37          59.09
# 124         0.000         0.000          0.00           0.00
# 125         0.000         0.000          0.00           0.00
#
#      SEPTIEMBRE'18(TN)  OCTUBRE'18(TN)  NOVIEMBRE'18(TN)  DICIEMBRE'18(TN)
# 0             5978.580        6511.400           6202.12          6753.440
# 1              185.040         198.700            191.04           198.700
# 2              573.560         701.280            690.86           783.460
# 3              117.560         146.040            141.40           126.460
# 4                0.000           0.000              0.00             0.000
# ..                 ...             ...               ...               ...
# 121              0.900           0.540              0.54             0.360
# 122              0.180           0.720              0.72             0.180
# 123             51.385          65.015             55.53            49.915
# 124              0.000           0.000              0.00             0.000
# 125              0.000           0.000              0.00             0.000
#
# [126 rows x 15 columns]

# %%
df_MA_18.columns
# Out:
# Index(['LOTE ', 'DISTRITO', 'FRACCIÓN', 'ENERO '18(TN)', 'FEBRERO '18(TN)',
#        'MARZO '18(TN)', 'ABRIL '18(TN)', 'MAYO '18(TN)', 'JUNIO'18(TN)',
#        'JULIO'18(TN)', 'AGOSTO'18(TN)', 'SEPTIEMBRE'18(TN)', 'OCTUBRE'18(TN)',
#        'NOVIEMBRE'18(TN)', 'DICIEMBRE'18(TN)'],
#       dtype='object')

# %%
import pandas as pd

def transformar_meses(df, meses):
    df = df.melt(id_vars=['LOTE ', 'DISTRITO', 'FRACCIÓN'], value_vars=meses, var_name='mes', value_name='valor')
    return df

# %%
meses = ['ENERO \'18(TN)', 'FEBRERO \'18(TN)', 'MARZO \'18(TN)', 'ABRIL \'18(TN)', 'MAYO \'18(TN)', 'JUNIO\'18(TN)',
         'JULIO\'18(TN)', 'AGOSTO\'18(TN)', 'SEPTIEMBRE\'18(TN)', 'OCTUBRE\'18(TN)', 'NOVIEMBRE\'18(TN)', 'DICIEMBRE\'18(TN)']
df_trans_18 = transformar_meses(df_MA_18,meses)
df_trans_18
# Out:
#       LOTE           DISTRITO                              FRACCIÓN
# 0         1        01. CENTRO                                 RESTO  \
# 1         1        01. CENTRO                               ENVASES
# 2         1        01. CENTRO                                VIDRIO
# 3         1        01. CENTRO                              CLINICOS
# 4         1        01. CENTRO                              ORGÁNICA
# ...     ...               ...                                   ...
# 1507      2  99. SIN DISTRITO               CONTENEDORES ROPA USADA
# 1508      3  99. SIN DISTRITO               CONTENEDORES ROPA USADA
# 1509      1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1510      2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1511      3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
#
#                    mes     valor
# 0        ENERO '18(TN)  6248.640
# 1        ENERO '18(TN)   159.280
# 2        ENERO '18(TN)   606.840
# 3        ENERO '18(TN)   130.760
# 4        ENERO '18(TN)     0.000
# ...                ...       ...
# 1507  DICIEMBRE'18(TN)     0.360
# 1508  DICIEMBRE'18(TN)     0.180
# 1509  DICIEMBRE'18(TN)    49.915
# 1510  DICIEMBRE'18(TN)     0.000
# 1511  DICIEMBRE'18(TN)     0.000
#
# [1512 rows x 5 columns]

# %%
df_trans_18['Año'] = 2018

# %%
df_MA_17 = pd.read_excel('datasets/Modelo_Residuos_2017.xlsx')
df_MA_17
# Out:
#         LOTE           DISTRITO                              FRACCIÓN
# 0           1        01. CENTRO                                 RESTO  \
# 1           1        01. CENTRO                               ENVASES
# 2           1        01. CENTRO                                VIDRIO
# 3           1        01. CENTRO                              CLINICOS
# 4           1        01. CENTRO                              ORGÁNICA
# ..        ...               ...                                   ...
# 123         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 124         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 125         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 126  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 127  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#      ENERO '17(TN)  FEBRERO '17(TN)  MARZO '17(TN)  ABRIL '17(TN)
# 0          5995.86          5562.30        6129.58       5975.840  \
# 1           138.06           130.56         142.44        135.640
# 2           503.50           448.42         514.22        510.960
# 3           127.48           127.20         145.26        118.900
# 4             0.00             0.00           0.00          0.000
# ..             ...              ...            ...            ...
# 123          56.43            52.53          42.86         40.119
# 124           0.00             0.00           0.00          0.000
# 125           0.00             0.00           0.00          0.000
# 126           9.22            36.52          36.13         22.380
# 127          51.94            42.43          58.31         40.140
#
#      MAYO '17(TN)  JUNIO'17(TN)  JULIO'17(TN)  AGOSTO'17(TN)
# 0         6500.54       6422.16      6027.780       5037.440  \
# 1          144.06        142.40       132.140        111.980
# 2          603.84        520.86       473.040        347.940
# 3          130.94        127.72       111.880         99.340
# 4            0.00          0.00         0.000          0.000
# ..            ...           ...           ...            ...
# 123         43.50         48.96        39.205         45.875
# 124          0.00          0.00         0.000          0.000
# 125          0.00          9.61         0.000          0.000
# 126         25.33         12.62        10.290          2.140
# 127         70.90         66.49        60.250         43.820
#
#      SEPTIEMBRE'17(TN)  OCTUBRE'17(TN)  NOVIEMBRE'17(TN)  DICIEMBRE'17(TN)
# 0              6013.96         6488.28          6163.420           6723.46
# 1               139.84          156.02           156.160            157.30
# 2               490.76          616.02           624.400            726.16
# 3               121.98          131.52           134.440            120.66
# 4                 0.00            0.00             0.000              0.00
# ..                 ...             ...               ...               ...
# 123              38.37           35.42            36.085             28.76
# 124               0.00            0.00             0.000              0.00
# 125               0.00            0.00             0.000              0.00
# 126              19.90           15.59            18.820             14.44
# 127              61.93           56.10            59.090             38.50
#
# [128 rows x 15 columns]

# %%
df_MA_17.columns
# Out:
# Index(['LOTE ', 'DISTRITO', 'FRACCIÓN', 'ENERO '17(TN)', 'FEBRERO '17(TN)',
#        'MARZO '17(TN)', 'ABRIL '17(TN)', 'MAYO '17(TN)', 'JUNIO'17(TN)',
#        'JULIO'17(TN)', 'AGOSTO'17(TN)', 'SEPTIEMBRE'17(TN)', 'OCTUBRE'17(TN)',
#        'NOVIEMBRE'17(TN)', 'DICIEMBRE'17(TN)'],
#       dtype='object')

# %%
meses = ['ENERO \'17(TN)', 'FEBRERO \'17(TN)', 'MARZO \'17(TN)', 'ABRIL \'17(TN)', 'MAYO \'17(TN)', 'JUNIO\'17(TN)',
         'JULIO\'17(TN)', 'AGOSTO\'17(TN)', 'SEPTIEMBRE\'17(TN)', 'OCTUBRE\'17(TN)', 'NOVIEMBRE\'17(TN)', 'DICIEMBRE\'17(TN)']
df_trans_17 = transformar_meses(df_MA_17,meses)
df_trans_17
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor
# 0        ENERO '17(TN)  5995.86
# 1        ENERO '17(TN)   138.06
# 2        ENERO '17(TN)   503.50
# 3        ENERO '17(TN)   127.48
# 4        ENERO '17(TN)     0.00
# ...                ...      ...
# 1531  DICIEMBRE'17(TN)    28.76
# 1532  DICIEMBRE'17(TN)     0.00
# 1533  DICIEMBRE'17(TN)     0.00
# 1534  DICIEMBRE'17(TN)    14.44
# 1535  DICIEMBRE'17(TN)    38.50
#
# [1536 rows x 5 columns]

# %%
df_trans_17['Año'] = 2017
df_trans_17
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor   Año
# 0        ENERO '17(TN)  5995.86  2017
# 1        ENERO '17(TN)   138.06  2017
# 2        ENERO '17(TN)   503.50  2017
# 3        ENERO '17(TN)   127.48  2017
# 4        ENERO '17(TN)     0.00  2017
# ...                ...      ...   ...
# 1531  DICIEMBRE'17(TN)    28.76  2017
# 1532  DICIEMBRE'17(TN)     0.00  2017
# 1533  DICIEMBRE'17(TN)     0.00  2017
# 1534  DICIEMBRE'17(TN)    14.44  2017
# 1535  DICIEMBRE'17(TN)    38.50  2017
#
# [1536 rows x 6 columns]

# %%
df_17_20=_concat_dataframes(df_trans_20,df_trans_19,df_trans_18,df_trans_17)
df_17_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor   Año
# 0        ENERO '20(TN)  6023.78  2020
# 1        ENERO '20(TN)   235.84  2020
# 2        ENERO '20(TN)   723.82  2020
# 3        ENERO '20(TN)   176.02  2020
# 4        ENERO '20(TN)     0.00  2020
# ...                ...      ...   ...
# 1531  DICIEMBRE'17(TN)    28.76  2017
# 1532  DICIEMBRE'17(TN)     0.00  2017
# 1533  DICIEMBRE'17(TN)     0.00  2017
# 1534  DICIEMBRE'17(TN)    14.44  2017
# 1535  DICIEMBRE'17(TN)    38.50  2017
#
# [6228 rows x 6 columns]

# %%
df_17_20['mes'].unique()
# Out:
# array(["ENERO '20(TN)", "FEBRERO '20(TN)", "MARZO '20(TN)",
#        "ABRIL '20(TN)", "MAYO '20(TN)", "JUNIO'20(TN)", "JULIO'20(TN)",
#        "AGOSTO'20(TN)", "SEPTIEMBRE'20(TN)", "OCTUBRE'20(TN)",
#        "NOVIEMBRE'20(TN)", "DICIEMBRE'20(TN)", "ENERO '19(TN)",
#        "FEBRERO '19(TN)", "MARZO '19(TN)", "ABRIL '19(TN)",
#        "MAYO '19(TN)", "JUNIO'19(TN)", "JULIO'19(TN)", "AGOSTO'19(TN)",
#        "SEPTIEMBRE'19(TN)", "OCTUBRE'19(TN)", "NOVIEMBRE'19(TN)",
#        "DICIEMBRE'19(TN)", "ENERO '18(TN)", "FEBRERO '18(TN)",
#        "MARZO '18(TN)", "ABRIL '18(TN)", "MAYO '18(TN)", "JUNIO'18(TN)",
#        "JULIO'18(TN)", "AGOSTO'18(TN)", "SEPTIEMBRE'18(TN)",
#        "OCTUBRE'18(TN)", "NOVIEMBRE'18(TN)", "DICIEMBRE'18(TN)",
#        "ENERO '17(TN)", "FEBRERO '17(TN)", "MARZO '17(TN)",
#        "ABRIL '17(TN)", "MAYO '17(TN)", "JUNIO'17(TN)", "JULIO'17(TN)",
#        "AGOSTO'17(TN)", "SEPTIEMBRE'17(TN)", "OCTUBRE'17(TN)",
#        "NOVIEMBRE'17(TN)", "DICIEMBRE'17(TN)"], dtype=object)

# %%
df_17_20["mes"] = df_17_20["mes"].apply(lambda x: x.split()[0].lower())
df_17_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#                    mes    valor   Año
# 0                enero  6023.78  2020
# 1                enero   235.84  2020
# 2                enero   723.82  2020
# 3                enero   176.02  2020
# 4                enero     0.00  2020
# ...                ...      ...   ...
# 1531  diciembre'17(tn)    28.76  2017
# 1532  diciembre'17(tn)     0.00  2017
# 1533  diciembre'17(tn)     0.00  2017
# 1534  diciembre'17(tn)    14.44  2017
# 1535  diciembre'17(tn)    38.50  2017
#
# [6228 rows x 6 columns]

# %%
df_17_20["mes"] = df_17_20["mes"].str.replace(r"\'\d{2}\(TN\)", "").str.lower()
df_17_20["mes"] = df_17_20["mes"].str.split("'").str[0]
df_17_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#             mes    valor   Año
# 0         enero  6023.78  2020
# 1         enero   235.84  2020
# 2         enero   723.82  2020
# 3         enero   176.02  2020
# 4         enero     0.00  2020
# ...         ...      ...   ...
# 1531  diciembre    28.76  2017
# 1532  diciembre     0.00  2017
# 1533  diciembre     0.00  2017
# 1534  diciembre    14.44  2017
# 1535  diciembre    38.50  2017
#
# [6228 rows x 6 columns]

# %%
df_17_20['mes'].unique()
# Out:
# array(['enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio',
#        'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre'],
#       dtype=object)

# %%
import pandas as pd
import re
df_17_20["mes"] = df_17_20["mes"].apply(lambda x: re.sub(r"'\d{2}\(TN\)", "", x) if isinstance(x, str) else x)
df_17_20
# Out:
#          LOTE           DISTRITO                              FRACCIÓN
# 0            1        01. CENTRO                                 RESTO  \
# 1            1        01. CENTRO                               ENVASES
# 2            1        01. CENTRO                                VIDRIO
# 3            1        01. CENTRO                              CLINICOS
# 4            1        01. CENTRO                              ORGÁNICA
# ...        ...               ...                                   ...
# 1531         1  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1532         2  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1533         3  99. SIN DISTRITO  RESIDUOS DEPOSITADOS MIGAS CALIENTES
# 1534  sin lote  99. SIN DISTRITO               Papel Incautado Policía
# 1535  sin lote  99. SIN DISTRITO                Cartón limpieza viaria
#
#             mes    valor   Año
# 0         enero  6023.78  2020
# 1         enero   235.84  2020
# 2         enero   723.82  2020
# 3         enero   176.02  2020
# 4         enero     0.00  2020
# ...         ...      ...   ...
# 1531  diciembre    28.76  2017
# 1532  diciembre     0.00  2017
# 1533  diciembre     0.00  2017
# 1534  diciembre    14.44  2017
# 1535  diciembre    38.50  2017
#
# [6228 rows x 6 columns]

# %%
df_20_21=concat_dataframes(df_MA_22,df_MA_21)
df_20_21
# Out:
#        Año        Mes  Lote          Fracción  Distrito
# 0     2022      enero     1      PAPEL-CARTON         1  \
# 1     2022      enero     1      PAPEL-CARTON         6
# 2     2022      enero     1      PAPEL-CARTON         7
# 3     2022      enero     1      PAPEL-CARTON         8
# 4     2022      enero     1      PAPEL-CARTON         9
# ...    ...        ...   ...               ...       ...
# 2133  2021  diciembre     3    PUNTOS LIMPIOS        13
# 2134  2021  diciembre     3    PUNTOS LIMPIOS        17
# 2135  2021  diciembre     3    PUNTOS LIMPIOS        18
# 2136  2021  diciembre     3  ANIMALES MUERTOS        99
# 2137  2021  diciembre     3             PILAS        99
#
#             Nombre Distrito  Toneladas
# 0                    Centro     395.86
# 1                    Tetuán     381.98
# 2                  Chamberí     312.76
# 3     Fuencarral - El Pardo     692.25
# 4         Moncloa - Aravaca     300.38
# ...                     ...        ...
# 2133     Puente de Vallecas      23.80
# 2134             Villaverde      37.66
# 2135      Villa de Vallecas      63.66
# 2136           Sin Distrito       8.62
# 2137           Sin Distrito       6.48
#
# [4332 rows x 7 columns]

# %%
df_20_21.columns
# Out:
# Index(['Año', 'Mes', 'Lote', 'Fracción', 'Distrito', 'Nombre Distrito',
#        'Toneladas'],
#       dtype='object')

# %%
def col_conversion(df, new_order, col_to_remove=None):
    df = df[new_order]
    if col_to_remove is not None:
        df.drop(col_to_remove, axis=1, inplace=True)
    return df

# %%
new_order = ['Lote', 'Nombre Distrito', 'Fracción', 'Mes', 'Toneladas', 'Año','Distrito']
df_final_20_21 = col_conversion(df_20_21, new_order, col_to_remove='Distrito')

# %%
df_final_20_21 = drop_rows(df_final_20_21, 'Fracción', ['CAMA DE CABALLO'])

# %%
df_final_20_21
# Out:
#       Lote        Nombre Distrito          Fracción        Mes  Toneladas
# 0        1                 Centro      PAPEL-CARTON      enero     395.86  \
# 1        1                 Tetuán      PAPEL-CARTON      enero     381.98
# 2        1               Chamberí      PAPEL-CARTON      enero     312.76
# 3        1  Fuencarral - El Pardo      PAPEL-CARTON      enero     692.25
# 4        1      Moncloa - Aravaca      PAPEL-CARTON      enero     300.38
# ...    ...                    ...               ...        ...        ...
# 2133     3     Puente de Vallecas    PUNTOS LIMPIOS  diciembre      23.80
# 2134     3             Villaverde    PUNTOS LIMPIOS  diciembre      37.66
# 2135     3      Villa de Vallecas    PUNTOS LIMPIOS  diciembre      63.66
# 2136     3           Sin Distrito  ANIMALES MUERTOS  diciembre       8.62
# 2137     3           Sin Distrito             PILAS  diciembre       6.48
#
#        Año
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 2133  2021
# 2134  2021
# 2135  2021
# 2136  2021
# 2137  2021
#
# [4308 rows x 6 columns]

# %%
def modify_column_values(df, column, value_dict):
    df[column] = df[column].replace(value_dict)
    return df

# %%
new_names = {'CARTON COMERCIAL': 'CARTÓN COMERCIAL', 'PAPEL-CARTON': 'PAPEL-CARTÓN', 'ORGANICA': 'ORGÁNICA', 'CONTENEDORES DE ROPA': 'ROPA USADA', 'ROPA': 'ROPA USADA'}
df_final_20_21 = modify_column_values(df_final_20_21, 'Fracción', new_names)
df_final_20_21['Fracción'].unique()
# Out:
# array(['PAPEL-CARTÓN', 'CARTÓN COMERCIAL', 'CLINICOS', 'ENVASES',
#        'ORGÁNICA', 'PUNTOS LIMPIOS', 'RCD', 'RESTO', 'VIDRIO',
#        'VIDRIO COMERCIAL', 'ROPA USADA', 'ANIMALES MUERTOS', 'PILAS'],
#       dtype=object)

# %%
df_final_20_21['Nombre Distrito'].unique()
# Out:
# array(['Centro', 'Tetuán', 'Chamberí', 'Fuencarral - El Pardo',
#        'Moncloa - Aravaca', 'Latina', 'Retiro', 'Salamanca', 'Chamartín',
#        'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Vicálvaro',
#        'San Blas - Canillejas', 'Barajas', 'Arganzuela', 'Carabanchel',
#        'Usera', 'Puente de Vallecas', 'Villaverde', 'Villa de Vallecas',
#        'Sin Distrito'], dtype=object)

# %%
new_names1 = {'CONTENEDORES ROPA USADA': 'ROPA USADA'}
df_17_20 = modify_column_values(df_17_20, 'FRACCIÓN', new_names1)
df_17_20['FRACCIÓN'].unique()
# Out:
# array(['RESTO', 'ENVASES', 'VIDRIO', 'CLINICOS', 'ORGÁNICA',
#        'PUNTOS LIMPIOS', 'PILAS', 'ANIMALES MUERTOS', 'CARTÓN COMERCIAL',
#        'PAPEL-CARTÓN', 'RCD', 'VIDRIO COMERCIAL', 'ROPA USADA',
#        'RESIDUOS DEPOSITADOS MIGAS CALIENTES', nan,
#        'Papel Incautado Policía', 'Cartón limpieza viaria'], dtype=object)

# %%
values_to_drop=['RESIDUOS DEPOSITADOS MIGAS CALIENTES','Papel Incautado Policía','Cartón limpieza viaria']
df_17_20 = drop_rows(df_17_20, 'FRACCIÓN', values_to_drop)
df_17_20['FRACCIÓN'].unique()
# Out:
# array(['RESTO', 'ENVASES', 'VIDRIO', 'CLINICOS', 'ORGÁNICA',
#        'PUNTOS LIMPIOS', 'PILAS', 'ANIMALES MUERTOS', 'CARTÓN COMERCIAL',
#        'PAPEL-CARTÓN', 'RCD', 'VIDRIO COMERCIAL', 'ROPA USADA'],
#       dtype=object)

# %%
df_final_20_21.sample()
# Out:
#      Lote Nombre Distrito Fracción      Mes  Toneladas   Año
# 308     2         Barajas   VIDRIO  febrero       78.8  2022

# %%
df_17_20.rename(columns={'LOTE ': 'Lote', 'DISTRITO': 'Nombre Distrito','FRACCIÓN':'Fracción','mes':'Mes','valor':'Toneladas'}, inplace=True)
df_17_20
# Out:
#      Lote   Nombre Distrito          Fracción        Mes  Toneladas   Año
# 0       1        01. CENTRO             RESTO      enero    6023.78  2020
# 1       1        01. CENTRO           ENVASES      enero     235.84  2020
# 2       1        01. CENTRO            VIDRIO      enero     723.82  2020
# 3       1        01. CENTRO          CLINICOS      enero     176.02  2020
# 4       1        01. CENTRO          ORGÁNICA      enero       0.00  2020
# ...   ...               ...               ...        ...        ...   ...
# 1526    2  99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre      58.94  2017
# 1527    3  99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre       4.40  2017
# 1528    1  99. SIN DISTRITO        ROPA USADA  diciembre       0.18  2017
# 1529    2  99. SIN DISTRITO        ROPA USADA  diciembre       0.36  2017
# 1530    3  99. SIN DISTRITO        ROPA USADA  diciembre       0.72  2017
#
# [5964 rows x 6 columns]

# %%
df_totals_recycling = pd.concat([df_final_20_21, df_17_20], axis=0)
df_totals_recycling
# Out:
#      Lote        Nombre Distrito          Fracción        Mes  Toneladas   Año
# 0       1                 Centro      PAPEL-CARTÓN      enero     395.86  2022
# 1       1                 Tetuán      PAPEL-CARTÓN      enero     381.98  2022
# 2       1               Chamberí      PAPEL-CARTÓN      enero     312.76  2022
# 3       1  Fuencarral - El Pardo      PAPEL-CARTÓN      enero     692.25  2022
# 4       1      Moncloa - Aravaca      PAPEL-CARTÓN      enero     300.38  2022
# ...   ...                    ...               ...        ...        ...   ...
# 1526    2       99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre      58.94  2017
# 1527    3       99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre       4.40  2017
# 1528    1       99. SIN DISTRITO        ROPA USADA  diciembre       0.18  2017
# 1529    2       99. SIN DISTRITO        ROPA USADA  diciembre       0.36  2017
# 1530    3       99. SIN DISTRITO        ROPA USADA  diciembre       0.72  2017
#
# [10272 rows x 6 columns]

# %%
df_totals_recycling
# Out:
#      Lote        Nombre Distrito          Fracción        Mes  Toneladas   Año
# 0       1                 Centro      PAPEL-CARTÓN      enero     395.86  2022
# 1       1                 Tetuán      PAPEL-CARTÓN      enero     381.98  2022
# 2       1               Chamberí      PAPEL-CARTÓN      enero     312.76  2022
# 3       1  Fuencarral - El Pardo      PAPEL-CARTÓN      enero     692.25  2022
# 4       1      Moncloa - Aravaca      PAPEL-CARTÓN      enero     300.38  2022
# ...   ...                    ...               ...        ...        ...   ...
# 1526    2       99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre      58.94  2017
# 1527    3       99. SIN DISTRITO  VIDRIO COMERCIAL  diciembre       4.40  2017
# 1528    1       99. SIN DISTRITO        ROPA USADA  diciembre       0.18  2017
# 1529    2       99. SIN DISTRITO        ROPA USADA  diciembre       0.36  2017
# 1530    3       99. SIN DISTRITO        ROPA USADA  diciembre       0.72  2017
#
# [10272 rows x 6 columns]

# %%
df_totals_recycling['Nombre Distrito'].unique()
# Out:
# array(['Centro', 'Tetuán', 'Chamberí', 'Fuencarral - El Pardo',
#        'Moncloa - Aravaca', 'Latina', 'Retiro', 'Salamanca', 'Chamartín',
#        'Moratalaz', 'Ciudad Lineal', 'Hortaleza', 'Vicálvaro',
#        'San Blas - Canillejas', 'Barajas', 'Arganzuela', 'Carabanchel',
#        'Usera', 'Puente de Vallecas', 'Villaverde', 'Villa de Vallecas',
#        'Sin Distrito', '01. CENTRO', '02. ARGANZUELA', '03. RETIRO',
#        '04. SALAMANCA', '05. CHAMARTÍN', '06. TETUAN', '07. CHAMBERÍ',
#        '08. FUENCARRAL', '09. MONCLOA - ARAVACA', '10. LATINA',
#        '11. CARABANCHEL', '12. USERA', '13. PUENTE DE VALLECAS',
#        '14. MORATALAZ', '15. CIUDAD LINEAL', '16. HORTALEZA',
#        '17. VILLAVERDE', '18. VILLA DE VALLECAS', '19. VICÁLVARO',
#        '20. SAN BLAS-CANILLEJAS', '21. BARAJAS', '99. SIN DISTRITO'],
#       dtype=object)

# %%
df_totals_recycling['Año'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017], dtype=int64)

# %%
def homogenize_district_names(df, district_column):
    def clean_district_name(value):
        value = re.sub(r'\d+\.\s*', '', value)
        value = value.capitalize()
        return value
    
    df = df.drop(df[(df[district_column].str.upper() == 'SIN DISTRITO') | (df[district_column].str.capitalize() == 'Sin distrito')].index)
    df[district_column] = df[district_column].apply(clean_district_name)
    
    return df

# %%
df_totals_recycling = homogenize_district_names(df_totals_recycling, 'Nombre Distrito')

# %%
new_names2 = {'San blas - canillejas': 'San blas-canillejas', 'Fuencarral': 'Fuencarral - el pardo','Tetuan':'Tetuán'}
df_totals_recycling = modify_column_values(df_totals_recycling, 'Nombre Distrito', new_names2)
df_totals_recycling['Nombre Distrito'].unique()
# Out:
# array(['Centro', 'Tetuán', 'Chamberí', 'Fuencarral - el pardo',
#        'Moncloa - aravaca', 'Latina', 'Retiro', 'Salamanca', 'Chamartín',
#        'Moratalaz', 'Ciudad lineal', 'Hortaleza', 'Vicálvaro',
#        'San blas-canillejas', 'Barajas', 'Arganzuela', 'Carabanchel',
#        'Usera', 'Puente de vallecas', 'Villaverde', 'Villa de vallecas'],
#       dtype=object)

# %% [markdown]
# LOCALIZACIONES

# %%
df_bins=pd.read_excel('datasets/Contenedores_varios.xlsx')

# %%
df_bins
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo
# 0                         181193           RESTO      CL_18  \
# 1                         181843           RESTO      CL_18
# 2                         178948           RESTO      CL_18
# 3                         181864           RESTO      CL_18
# 4                         181872           RESTO      CL_13
# ...                          ...             ...        ...
# 43632                     401538    PAPEL-CARTON  IG_21_228
# 43633                     401538          VIDRIO  IG_21_228
# 43634                     401540          VIDRIO  IG_21_229
# 43635                     405504    PAPEL-CARTON  IG_21_230
# 43636                     405504          VIDRIO  IG_21_230
#
#              Descripcion Modelo  Cantidad  Lote            Distrito  Barrio
# 0                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN  \
# 1                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 2                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 3                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 4                   Res 3200 CL         1     3  PUENTE DE VALLECAS     NaN
# ...                         ...       ...   ...                 ...     ...
# 43632  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43633   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43634   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43635  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43636   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
#
#       Tipo Vía                 Nombre  Número   COORDENADA X  COORDENADA Y
# 0        CALLE    DE LA SIERRA ESPUÑA     4.0  447109.710000  4.469732e+06  \
# 1        CALLE  DEL PUERTO DE POZAZAL     1.0  446615.250000  4.470062e+06
# 2        CALLE       TRES MERCAMADRID     5.0  443017.320000  4.467824e+06
# 3        CALLE       DE LA PEÑA NUEVA    55.0  447358.450000  4.469066e+06
# 4        CALLE          DE MONTANCHEZ    14.0  443039.130000  4.469446e+06
# ...        ...                    ...     ...            ...           ...
# 43632    CALLE      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06
# 43633    CALLE      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06
# 43634    CALLE                  TURIN     2.0  447810.168902  4.479313e+06
# 43635    CALLE                MISTRAL     4.0  449359.468943  4.480392e+06
# 43636    CALLE                MISTRAL     4.0  449359.468943  4.480392e+06
#
#        LONGITUD    LATITUD                       DIRECCION
# 0     -3.623050  40.376498    CALLE DE LA SIERRA ESPUÑA, 4
# 1     -3.628902  40.379437  CALLE DEL PUERTO DE POZAZAL, 1
# 2     -3.671085  40.359038       CALLE TRES MERCAMADRID, 5
# 3     -3.620065  40.370510      CALLE DE LA PEÑA NUEVA, 55
# 4     -3.670973  40.373649         CALLE DE MONTANCHEZ, 14
# ...         ...        ...                             ...
# 43632 -3.590327  40.473977     CALLE PLAYA DE SAN JUAN, 16
# 43633 -3.590327  40.473977     CALLE PLAYA DE SAN JUAN, 16
# 43634 -3.615585  40.462848                  CALLE TURIN, 2
# 43635 -3.597398  40.472664                CALLE MISTRAL, 4
# 43636 -3.597398  40.472664                CALLE MISTRAL, 4
#
# [43637 rows x 16 columns]

# %%
null_count = df_bins['LONGITUD'].isnull().sum()
null_count
# Out:
# 0

# %%
duplicates_count = df_bins.duplicated().sum()
duplicates_count
# Out:
# 8667

# %%
null_count = df_bins['Tipo Contenedor'].isnull().sum()
null_count
# Out:
# 0

# %%
def clean_data(df):
    df.drop_duplicates(inplace=True)
    return df

# %%
clean_data(df_bins)
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo
# 0                         181193           RESTO      CL_18  \
# 1                         181843           RESTO      CL_18
# 2                         178948           RESTO      CL_18
# 3                         181864           RESTO      CL_18
# 4                         181872           RESTO      CL_13
# ...                          ...             ...        ...
# 43632                     401538    PAPEL-CARTON  IG_21_228
# 43633                     401538          VIDRIO  IG_21_228
# 43634                     401540          VIDRIO  IG_21_229
# 43635                     405504    PAPEL-CARTON  IG_21_230
# 43636                     405504          VIDRIO  IG_21_230
#
#              Descripcion Modelo  Cantidad  Lote            Distrito  Barrio
# 0                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN  \
# 1                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 2                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 3                   Res 3200 CL         1     3   VILLA DE VALLECAS     NaN
# 4                   Res 3200 CL         1     3  PUENTE DE VALLECAS     NaN
# ...                         ...       ...   ...                 ...     ...
# 43632  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43633   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43634   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43635  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
# 43636   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS     NaN
#
#       Tipo Vía                 Nombre  Número   COORDENADA X  COORDENADA Y
# 0        CALLE    DE LA SIERRA ESPUÑA     4.0  447109.710000  4.469732e+06  \
# 1        CALLE  DEL PUERTO DE POZAZAL     1.0  446615.250000  4.470062e+06
# 2        CALLE       TRES MERCAMADRID     5.0  443017.320000  4.467824e+06
# 3        CALLE       DE LA PEÑA NUEVA    55.0  447358.450000  4.469066e+06
# 4        CALLE          DE MONTANCHEZ    14.0  443039.130000  4.469446e+06
# ...        ...                    ...     ...            ...           ...
# 43632    CALLE      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06
# 43633    CALLE      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06
# 43634    CALLE                  TURIN     2.0  447810.168902  4.479313e+06
# 43635    CALLE                MISTRAL     4.0  449359.468943  4.480392e+06
# 43636    CALLE                MISTRAL     4.0  449359.468943  4.480392e+06
#
#        LONGITUD    LATITUD                       DIRECCION
# 0     -3.623050  40.376498    CALLE DE LA SIERRA ESPUÑA, 4
# 1     -3.628902  40.379437  CALLE DEL PUERTO DE POZAZAL, 1
# 2     -3.671085  40.359038       CALLE TRES MERCAMADRID, 5
# 3     -3.620065  40.370510      CALLE DE LA PEÑA NUEVA, 55
# 4     -3.670973  40.373649         CALLE DE MONTANCHEZ, 14
# ...         ...        ...                             ...
# 43632 -3.590327  40.473977     CALLE PLAYA DE SAN JUAN, 16
# 43633 -3.590327  40.473977     CALLE PLAYA DE SAN JUAN, 16
# 43634 -3.615585  40.462848                  CALLE TURIN, 2
# 43635 -3.597398  40.472664                CALLE MISTRAL, 4
# 43636 -3.597398  40.472664                CALLE MISTRAL, 4
#
# [34970 rows x 16 columns]

# %%
df_bins['Tipo Contenedor'].unique()
# Out:
# array(['RESTO', 'PAPEL-CARTON', 'ENVASES', 'ORGANICA', 'VIDRIO'],
#       dtype=object)

# %%
df_bins['Código Interno del Situad'].value_counts()
# Out:
# Código Interno del Situad
# 919108    5
# 183849    4
# 183842    4
# 183800    4
# 182282    4
#          ..
# 164880    1
# 164998    1
# 182193    1
# 340263    1
# 182748    1
# Name: count, Length: 14170, dtype: int64

# %%
df_bins.columns
# Out:
# Index(['Código Interno del Situad', 'Tipo Contenedor', 'Modelo',
#        'Descripcion Modelo', 'Cantidad', 'Lote', 'Distrito', 'Barrio',
#        'Tipo Vía', 'Nombre', 'Número', 'COORDENADA X', 'COORDENADA Y',
#        'LONGITUD', 'LATITUD', 'DIRECCION'],
#       dtype='object')

# %%
import pandas as pd

def rename_columns_and_add_country(df):
    rename_col = {
        'Código Interno del Situad': 'Código_interno',
        'Tipo Contenedor': 'Tipo_Contenedor',
        'Descripcion Modelo': 'Descripción_Modelo',
        'DIRECCION': 'Dirección'}
    df = df.rename(columns=rename_col)
    df['País'] = 'España'
    df['Ciudad'] = 'Madrid'
    return df

# %%
df_bins = rename_columns_and_add_country(df_bins)
df_bins
# Out:
#        Código_interno Tipo_Contenedor     Modelo        Descripción_Modelo
# 0              181193           RESTO      CL_18               Res 3200 CL  \
# 1              181843           RESTO      CL_18               Res 3200 CL
# 2              178948           RESTO      CL_18               Res 3200 CL
# 3              181864           RESTO      CL_18               Res 3200 CL
# 4              181872           RESTO      CL_13               Res 3200 CL
# ...               ...             ...        ...                       ...
# 43632          401538    PAPEL-CARTON  IG_21_228  PC 3000 CAMPANA PE ADAPT
# 43633          401538          VIDRIO  IG_21_228   V 3000 CAMPANA PE ADAPT
# 43634          401540          VIDRIO  IG_21_229   V 3000 CAMPANA PE ADAPT
# 43635          405504    PAPEL-CARTON  IG_21_230  PC 3000 CAMPANA PE ADAPT
# 43636          405504          VIDRIO  IG_21_230   V 3000 CAMPANA PE ADAPT
#
#        Cantidad  Lote            Distrito  Barrio Tipo Vía
# 0             1     3   VILLA DE VALLECAS     NaN    CALLE  \
# 1             1     3   VILLA DE VALLECAS     NaN    CALLE
# 2             1     3   VILLA DE VALLECAS     NaN    CALLE
# 3             1     3   VILLA DE VALLECAS     NaN    CALLE
# 4             1     3  PUENTE DE VALLECAS     NaN    CALLE
# ...         ...   ...                 ...     ...      ...
# 43632         1     2             BARAJAS     NaN    CALLE
# 43633         1     2             BARAJAS     NaN    CALLE
# 43634         1     2             BARAJAS     NaN    CALLE
# 43635         1     2             BARAJAS     NaN    CALLE
# 43636         1     2             BARAJAS     NaN    CALLE
#
#                       Nombre  Número   COORDENADA X  COORDENADA Y  LONGITUD
# 0        DE LA SIERRA ESPUÑA     4.0  447109.710000  4.469732e+06 -3.623050  \
# 1      DEL PUERTO DE POZAZAL     1.0  446615.250000  4.470062e+06 -3.628902
# 2           TRES MERCAMADRID     5.0  443017.320000  4.467824e+06 -3.671085
# 3           DE LA PEÑA NUEVA    55.0  447358.450000  4.469066e+06 -3.620065
# 4              DE MONTANCHEZ    14.0  443039.130000  4.469446e+06 -3.670973
# ...                      ...     ...            ...           ...       ...
# 43632      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06 -3.590327
# 43633      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06 -3.590327
# 43634                  TURIN     2.0  447810.168902  4.479313e+06 -3.615585
# 43635                MISTRAL     4.0  449359.468943  4.480392e+06 -3.597398
# 43636                MISTRAL     4.0  449359.468943  4.480392e+06 -3.597398
#
#          LATITUD                       Dirección    País  Ciudad
# 0      40.376498    CALLE DE LA SIERRA ESPUÑA, 4  España  Madrid
# 1      40.379437  CALLE DEL PUERTO DE POZAZAL, 1  España  Madrid
# 2      40.359038       CALLE TRES MERCAMADRID, 5  España  Madrid
# 3      40.370510      CALLE DE LA PEÑA NUEVA, 55  España  Madrid
# 4      40.373649         CALLE DE MONTANCHEZ, 14  España  Madrid
# ...          ...                             ...     ...     ...
# 43632  40.473977     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 43633  40.473977     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 43634  40.462848                  CALLE TURIN, 2  España  Madrid
# 43635  40.472664                CALLE MISTRAL, 4  España  Madrid
# 43636  40.472664                CALLE MISTRAL, 4  España  Madrid
#
# [34970 rows x 18 columns]

# %%
def check_nan(df):
    nan_couns=df.isna().sum()
    return nan_couns

# %%
total=check_nan(df_bins)
total
# Out:
# Código_interno            0
# Tipo_Contenedor           0
# Modelo                    0
# Descripción_Modelo        0
# Cantidad                  0
# Lote                      0
# Distrito                  0
# Barrio                34970
# Tipo Vía                  0
# Nombre                    0
# Número                   66
# COORDENADA X              0
# COORDENADA Y              0
# LONGITUD                  0
# LATITUD                   0
# Dirección                 0
# País                      0
# Ciudad                    0
# dtype: int64

# %%
def remove_columns(df, col):
    df = df.drop(columns=col)
    return df

# %%
df_bins=remove_columns(df_bins,'Barrio')
df_bins
# Out:
#        Código_interno Tipo_Contenedor     Modelo        Descripción_Modelo
# 0              181193           RESTO      CL_18               Res 3200 CL  \
# 1              181843           RESTO      CL_18               Res 3200 CL
# 2              178948           RESTO      CL_18               Res 3200 CL
# 3              181864           RESTO      CL_18               Res 3200 CL
# 4              181872           RESTO      CL_13               Res 3200 CL
# ...               ...             ...        ...                       ...
# 43632          401538    PAPEL-CARTON  IG_21_228  PC 3000 CAMPANA PE ADAPT
# 43633          401538          VIDRIO  IG_21_228   V 3000 CAMPANA PE ADAPT
# 43634          401540          VIDRIO  IG_21_229   V 3000 CAMPANA PE ADAPT
# 43635          405504    PAPEL-CARTON  IG_21_230  PC 3000 CAMPANA PE ADAPT
# 43636          405504          VIDRIO  IG_21_230   V 3000 CAMPANA PE ADAPT
#
#        Cantidad  Lote            Distrito Tipo Vía                 Nombre
# 0             1     3   VILLA DE VALLECAS    CALLE    DE LA SIERRA ESPUÑA  \
# 1             1     3   VILLA DE VALLECAS    CALLE  DEL PUERTO DE POZAZAL
# 2             1     3   VILLA DE VALLECAS    CALLE       TRES MERCAMADRID
# 3             1     3   VILLA DE VALLECAS    CALLE       DE LA PEÑA NUEVA
# 4             1     3  PUENTE DE VALLECAS    CALLE          DE MONTANCHEZ
# ...         ...   ...                 ...      ...                    ...
# 43632         1     2             BARAJAS    CALLE      PLAYA DE SAN JUAN
# 43633         1     2             BARAJAS    CALLE      PLAYA DE SAN JUAN
# 43634         1     2             BARAJAS    CALLE                  TURIN
# 43635         1     2             BARAJAS    CALLE                MISTRAL
# 43636         1     2             BARAJAS    CALLE                MISTRAL
#
#        Número   COORDENADA X  COORDENADA Y  LONGITUD    LATITUD
# 0         4.0  447109.710000  4.469732e+06 -3.623050  40.376498  \
# 1         1.0  446615.250000  4.470062e+06 -3.628902  40.379437
# 2         5.0  443017.320000  4.467824e+06 -3.671085  40.359038
# 3        55.0  447358.450000  4.469066e+06 -3.620065  40.370510
# 4        14.0  443039.130000  4.469446e+06 -3.670973  40.373649
# ...       ...            ...           ...       ...        ...
# 43632    16.0  449959.824347  4.480534e+06 -3.590327  40.473977
# 43633    16.0  449959.824347  4.480534e+06 -3.590327  40.473977
# 43634     2.0  447810.168902  4.479313e+06 -3.615585  40.462848
# 43635     4.0  449359.468943  4.480392e+06 -3.597398  40.472664
# 43636     4.0  449359.468943  4.480392e+06 -3.597398  40.472664
#
#                             Dirección    País  Ciudad
# 0        CALLE DE LA SIERRA ESPUÑA, 4  España  Madrid
# 1      CALLE DEL PUERTO DE POZAZAL, 1  España  Madrid
# 2           CALLE TRES MERCAMADRID, 5  España  Madrid
# 3          CALLE DE LA PEÑA NUEVA, 55  España  Madrid
# 4             CALLE DE MONTANCHEZ, 14  España  Madrid
# ...                               ...     ...     ...
# 43632     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 43633     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 43634                  CALLE TURIN, 2  España  Madrid
# 43635                CALLE MISTRAL, 4  España  Madrid
# 43636                CALLE MISTRAL, 4  España  Madrid
#
# [34970 rows x 17 columns]

# %%
def convert_index_to_column(df, column_name):
    df = df.reset_index()
    df = df.rename(columns={'index': column_name})
    return df

# %%
df_bins=convert_index_to_column(df_bins,'Num_único')
df_bins
# Out:
#        Num_único  Código_interno Tipo_Contenedor     Modelo
# 0              0          181193           RESTO      CL_18  \
# 1              1          181843           RESTO      CL_18
# 2              2          178948           RESTO      CL_18
# 3              3          181864           RESTO      CL_18
# 4              4          181872           RESTO      CL_13
# ...          ...             ...             ...        ...
# 34965      43632          401538    PAPEL-CARTON  IG_21_228
# 34966      43633          401538          VIDRIO  IG_21_228
# 34967      43634          401540          VIDRIO  IG_21_229
# 34968      43635          405504    PAPEL-CARTON  IG_21_230
# 34969      43636          405504          VIDRIO  IG_21_230
#
#              Descripción_Modelo  Cantidad  Lote            Distrito Tipo Vía
# 0                   Res 3200 CL         1     3   VILLA DE VALLECAS    CALLE  \
# 1                   Res 3200 CL         1     3   VILLA DE VALLECAS    CALLE
# 2                   Res 3200 CL         1     3   VILLA DE VALLECAS    CALLE
# 3                   Res 3200 CL         1     3   VILLA DE VALLECAS    CALLE
# 4                   Res 3200 CL         1     3  PUENTE DE VALLECAS    CALLE
# ...                         ...       ...   ...                 ...      ...
# 34965  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS    CALLE
# 34966   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS    CALLE
# 34967   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS    CALLE
# 34968  PC 3000 CAMPANA PE ADAPT         1     2             BARAJAS    CALLE
# 34969   V 3000 CAMPANA PE ADAPT         1     2             BARAJAS    CALLE
#
#                       Nombre  Número   COORDENADA X  COORDENADA Y  LONGITUD
# 0        DE LA SIERRA ESPUÑA     4.0  447109.710000  4.469732e+06 -3.623050  \
# 1      DEL PUERTO DE POZAZAL     1.0  446615.250000  4.470062e+06 -3.628902
# 2           TRES MERCAMADRID     5.0  443017.320000  4.467824e+06 -3.671085
# 3           DE LA PEÑA NUEVA    55.0  447358.450000  4.469066e+06 -3.620065
# 4              DE MONTANCHEZ    14.0  443039.130000  4.469446e+06 -3.670973
# ...                      ...     ...            ...           ...       ...
# 34965      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06 -3.590327
# 34966      PLAYA DE SAN JUAN    16.0  449959.824347  4.480534e+06 -3.590327
# 34967                  TURIN     2.0  447810.168902  4.479313e+06 -3.615585
# 34968                MISTRAL     4.0  449359.468943  4.480392e+06 -3.597398
# 34969                MISTRAL     4.0  449359.468943  4.480392e+06 -3.597398
#
#          LATITUD                       Dirección    País  Ciudad
# 0      40.376498    CALLE DE LA SIERRA ESPUÑA, 4  España  Madrid
# 1      40.379437  CALLE DEL PUERTO DE POZAZAL, 1  España  Madrid
# 2      40.359038       CALLE TRES MERCAMADRID, 5  España  Madrid
# 3      40.370510      CALLE DE LA PEÑA NUEVA, 55  España  Madrid
# 4      40.373649         CALLE DE MONTANCHEZ, 14  España  Madrid
# ...          ...                             ...     ...     ...
# 34965  40.473977     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 34966  40.473977     CALLE PLAYA DE SAN JUAN, 16  España  Madrid
# 34967  40.462848                  CALLE TURIN, 2  España  Madrid
# 34968  40.472664                CALLE MISTRAL, 4  España  Madrid
# 34969  40.472664                CALLE MISTRAL, 4  España  Madrid
#
# [34970 rows x 18 columns]

# %%
df_bins.to_excel('df_bins2.xlsx', index=True)
df_bins.to_csv('df_bins2.csv', index=True)

# %%
df_totals_recycling.to_excel('datasets/total_collected.xlsx', index=True)

# %% [markdown]
# #
